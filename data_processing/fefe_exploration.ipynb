# %% [markdown]
# ## FEFE DATA EXLORATION

# %% [markdown]
# #### 1. FIX DATASET -> ASSOCIATE COMPONENTS WITH BODE CODE

# %%
# 1 - initial dataframe exploration from chris
import pandas as pd
datapath = "../data/raw/componentwise_dataset.xlsx"
df = pd.read_excel(datapath, sheet_name="Export")

cols_en = [
"Fault start date (MEL)",
"Short text (MEL)",
"Long text (MEL)",
"Message number (MEL)",
"Vehicle family (TPL)",
"Vehicle type (TPL)",
"Material (CO)",
"Material reference (MAT)",
"Material quantity ACTUAL",
"Material / unit of measure (CO)",
"WF screen symptom (MEL)",
"WF-cause-sys-1 (MEL) (H)",
"WF-cause-sys-2 (MEL) (H)",
"WF-Cause-Sys-3 (MEL) (H)",
"WF-Cause-Sys-4 (MEL) (H)",
"WF-Cause-Sys-5 (MEL) (H)",
"WF-cause-sys-6 (MEL) (H)",
"WF cause failure type (MEL)",
"WF-cause-fix.mass (1-3) (MEL)",
"Multiple unit / EW (TPL)",
"Functional location (TPL)",
"DIN code (H)",
"Design workstation (location) (MEL)"
]

cols_interst = [
"Fault start date (MEL)",
"Short text (MEL)",
"Long text (MEL)",
"Message number (MEL)",
"Material reference (MAT)",
"WF cause failure type (MEL)",
"WF-cause-fix.mass (1-3) (MEL)",
"Multiple unit / EW (TPL)",

]
df = df.loc[:1594]

df.columns = cols_en
df = df[cols_interst]

df.rename(columns={"Message number (MEL)" : "log_number",
                   "Multiple unit / EW (TPL)": "train_number",
                   "Fault start date (MEL)" : "fault_start_date",
                   "Short text (MEL)" : "problem",
                   "Long text (MEL)" : "maintenance_log",
                   "Material reference (MAT)": "material_description",
                   "WF cause failure type (MEL)": "cause_of_failure",
                   "WF-cause-fix.mass (1-3) (MEL)": "maintenance_steps",
                   "Material reference (MAT)": "material_name"}
                   , inplace=True)

df["fault_start_date"] = pd.to_datetime(df["fault_start_date"], format="%Y-%m-%d %H:%M:%S")
df["problem"] = df["problem"].astype(str)
df["maintenance_log"] = df["maintenance_log"].astype(str)
df["log_number"] = df["log_number"].astype(int)
df["train_number"] = df["train_number"].astype(str)
df["material_name"] = df["material_name"].astype(str)
df["maintenance_steps"] = df["maintenance_steps"].astype(str)
df["cause_of_failure"] = df["cause_of_failure"].astype(str)

# Ok it is always the same. Remove the prefix:
df["train_number"]= df["train_number"].str[10:]

# Reorder columns
df = df[["train_number", "problem", "log_number", "maintenance_log", "fault_start_date", 
         "material_name", "maintenance_steps", "cause_of_failure"]]

# %%
# 2.2 - associate components to bode code
components_bode_dict = {
    'SICHERHEITSGLAS': '25-351-0224-301',
    'ZAHNRIEMENRAD': '25-865-0011-301',
    'DREHFALLE': '25-341-0119-101',
    'TÜRSTEUERUNG': '25-004-1019-301',
    'FÜHRUNGSSCHIENE': '25-326-0300-201',
    'TÜRFLÜGEL': '25-310-0566-202'
    

}

# keep only rows that have one of these components
def search_material_reference(row, search_dict):
    for key in search_dict.keys():
        if key.lower() in row['material_name'].lower() or key.lower() in row['problem'].lower():
            return True
    return False

filtered_df = df[df.apply(lambda row: search_material_reference(row, components_bode_dict), axis=1)]
filtered_df = filtered_df.drop_duplicates()

# add bode code
def add_bode_code(row, search_dict):
    for key, code in search_dict.items():
        if key.lower() in row['material_name'].lower() or key.lower() in row['problem'].lower():
            return code
    return None

filtered_df['BODE code'] = filtered_df.apply(lambda row: add_bode_code(row, components_bode_dict), axis=1)
print(filtered_df)
# Out:
#      train_number                                 problem  log_number  \
# 8           015-5                Primärdrehfalle tauschen   131479425
# 9           001-5  -ET-Antriebsmotor 1 gestört-zeitwei...   131471966
# 13          047-8                -ET-Rechner 3 Stör.Aktiv   131461040
# 15          043-7            -ÜT-Türrechner WE1 abgenutzt   131460609
# 46          023-9           -ET-Rechner 2 schliesst nicht   131351602
# ...           ...                                     ...         ...
# 1557        024-7                  ET-Verriegelung 3 lose   128275990
# 1567        046-0     ET-v-Schwelle Notent 3 schwergängig   128189630
# 1569        056-9             -Türsteuerung Zug 2 pendelt   128140205
# 1570        056-9             -Türsteuerung Zug 2 pendelt   128140205
# 1594        009-8                ET-Türblatt L korrodiert   127402644
#
#                                         maintenance_log fault_start_date  \
# 8      * 18.09.2024 12:56:19 CET (U239359) * System ...       2024-09-18
# 9      * 17.09.2024 09:18:21 CET (U147283) Tel. +41 ...       2024-09-17
# 13     * 14.09.2024 06:23:11 CET (U224474) Tel. +41 ...       2024-09-14
# 15    * 13.09.2024 21:30:31 CET (U146319) Tel. +41 5...       2024-09-13
# 46     * 18.08.2024 13:41:57 CET (U230689) Tel. +41 ...       2024-08-18
# ...                                                 ...              ...
# 1557   * 26.07.2022 03:30:01 CET (U228671) Tel. +41 ...       2022-07-26
# 1567   * 04.07.2022 10:10:33 CET (U225459) Tel. +41 ...       2022-07-04
# 1569   * 21.06.2022 08:03:57 CET (U208200) Tel. +41 ...       2022-06-21
# 1570   * 21.06.2022 08:03:57 CET (U208200) Tel. +41 ...       2022-06-21
# 1594   * 16.12.2021 10:15:23 CET (E536942) * System ...       2021-12-16
#
#                                  material_name  \
# 8       Drehfalle vollständig zu Einstiegstüre
# 9            Türsteuerung BODE 25-004-1019-301
# 13      Drehfalle vollständig zu Einstiegstüre
# 15    Türsteuerung MTS-L 1.14 zu Uebergangstür
# 46                   Handschalter zu Türflügel
# ...                                        ...
# 1557    Drehfalle vollständig zu Einstiegstüre
# 1567    Drehfalle vollständig zu Einstiegstüre
# 1569         Reinigungsset für SBB-Instrumente
# 1570   Flachkopf-TORX-Schraube M6x8 mit Tuflok
# 1594      Türflügel mit Öffner 25-310-0566-202
#
#                                       maintenance_steps  \
# 8             Sonstige → Test / Simulation durchgeführt
# 9                          HW/Elektr. & Mech. → ersetzt
# 13    HW/Elektr. & Mech. → ersetzt ; HW/Elektr. & Me...
# 15    HW/Elektr. & Mech. → ersetzt ; Software → Upda...
# 46                         HW/Elektr. & Mech. → ersetzt
# ...                                                 ...
# 1557                       HW/Elektr. & Mech. → ersetzt
# 1567  HW/Elektr. & Mech. → eingestellt / justiert ; ...
# 1569  HW/Elektr. & Mech. → ersetzt ; HW/Elektr. & Me...
# 1570  HW/Elektr. & Mech. → ersetzt ; HW/Elektr. & Me...
# 1594  Sonstige → geprüft gem. Checkliste ; Sonstige ...
#
#                                        cause_of_failure        BODE code
# 8                Software & Firmware → übrige Störungen  25-341-0119-101
# 9     HW/Elektr. & Mech. - elektrisch → spricht nich...  25-004-1019-301
# 13    HW/Elektr. & Mech. - elektrisch → Fehler Daten...  25-341-0119-101
# 15               Software & Firmware → übrige Störungen  25-004-1019-301
# 46    HW/Elektr. & Mech. - elektrisch → spricht unbe...  25-310-0566-202
# ...                                                 ...              ...
# 1557  HW/Elektr. & Mech. - mechanisch → lose / unzur...  25-341-0119-101
# 1567  HW/Elektr. & Mech. - mechanisch → blockiert / ...  25-341-0119-101
# 1569  HW/Elektr. & Mech. - mechanisch → blockiert / ...  25-004-1019-301
# 1570  HW/Elektr. & Mech. - mechanisch → blockiert / ...  25-004-1019-301
# 1594  HW/Elektr. & Mech. - mechanisch → Oberfläche k...  25-310-0566-202
#
# [191 rows x 9 columns]

# %%
# 3 - save df
filtered_df.to_csv("../data/interim/final_df.csv", index=False)

# %%
filtered_df.head()
# Out:
#    train_number                                 problem  log_number  \
# 8         015-5                Primärdrehfalle tauschen   131479425
# 9         001-5  -ET-Antriebsmotor 1 gestört-zeitwei...   131471966
# 13        047-8                -ET-Rechner 3 Stör.Aktiv   131461040
# 15        043-7            -ÜT-Türrechner WE1 abgenutzt   131460609
# 46        023-9           -ET-Rechner 2 schliesst nicht   131351602
#
#                                       maintenance_log fault_start_date  \
# 8    * 18.09.2024 12:56:19 CET (U239359) * System ...       2024-09-18
# 9    * 17.09.2024 09:18:21 CET (U147283) Tel. +41 ...       2024-09-17
# 13   * 14.09.2024 06:23:11 CET (U224474) Tel. +41 ...       2024-09-14
# 15  * 13.09.2024 21:30:31 CET (U146319) Tel. +41 5...       2024-09-13
# 46   * 18.08.2024 13:41:57 CET (U230689) Tel. +41 ...       2024-08-18
#
#                                material_name  \
# 8     Drehfalle vollständig zu Einstiegstüre
# 9          Türsteuerung BODE 25-004-1019-301
# 13    Drehfalle vollständig zu Einstiegstüre
# 15  Türsteuerung MTS-L 1.14 zu Uebergangstür
# 46                 Handschalter zu Türflügel
#
#                                     maintenance_steps  \
# 8           Sonstige → Test / Simulation durchgeführt
# 9                        HW/Elektr. & Mech. → ersetzt
# 13  HW/Elektr. & Mech. → ersetzt ; HW/Elektr. & Me...
# 15  HW/Elektr. & Mech. → ersetzt ; Software → Upda...
# 46                       HW/Elektr. & Mech. → ersetzt
#
#                                      cause_of_failure        BODE code
# 8              Software & Firmware → übrige Störungen  25-341-0119-101
# 9   HW/Elektr. & Mech. - elektrisch → spricht nich...  25-004-1019-301
# 13  HW/Elektr. & Mech. - elektrisch → Fehler Daten...  25-341-0119-101
# 15             Software & Firmware → übrige Störungen  25-004-1019-301
# 46  HW/Elektr. & Mech. - elektrisch → spricht unbe...  25-310-0566-202

# %% [markdown]
# #### 2. WORK ON MAINTENANCE LOG COLUMN

# %%
import pandas as pd
import json
import re

df = filtered_df
# extract log
def extract_logs(maintenance_log):
    log_pattern = r'(\d{2}\.\d{2}\.\d{4} \d{2}:\d{2}:\d{2}) CET \((U\d+)\).*?(\*.*?)(?=(\d{2}\.\d{2}\.\d{4} \d{2}:\d{2}:\d{2}) CET|\Z)'
    matches = re.findall(log_pattern, maintenance_log, re.DOTALL)
    logs = []
    for match in matches:
        log = {
            "date_time": match[0],
            "comment": match[2].strip(),
        }
        logs.append(log)
    
    return logs

log_dict = {}
for index, row in df.iterrows():
    logs = extract_logs(row['maintenance_log'])
    print(logs)
    for i, log in enumerate(logs):
        key = f"issue_{int(row['log_number'])}_log_{i+1}"
        log_dict[key] = log
# Out:
# [{'date_time': '18.09.2024 12:56:19', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (Störungsursache): * Türe 3 * * Symptom (Störungsbild): * lose * *'}, {'date_time': '18.09.2024 12:55:02', 'comment': '*'}, {'date_time': '18.09.2024 12:54:54', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (Störungsursache): * Türe 1 * * Symptom (Störungsbild): * lose * *'}, {'date_time': '18.09.2024 12:54:39', 'comment': '* Beim Kontrollauftrag/Änderungsauftrag Bolzenmarkierung wurde an der MT23   eine Drehfalle mit gebrochenem Siegellack an der Mutter des Bolzens   gefunden. Die Mutter des Bolzens war lose. * Mutter wurde wieder angezogen. * Die Primärdrehfalle 94-000-1950A muss beim nächsten UH ersetzt werden *'}, {'date_time': '20.09.2024 16:11:04', 'comment': '* Ausfallart (Störungsursache): * übrige Störungen * * System BHM 1 (Störungsursache): * Ver-/ Entriegelungseinheit * * Behebungsmassnahme 1 (Störungsursache): * Test / Simulation durchgeführt * * System BHM 2 (Störungsursache): * Ver-/ Entriegelungseinheit * *'}, {'date_time': '20.09.2024 16:11:04', 'comment': '* Diag: Drehfallen an Lager waren nicht markiert. * Mass: Drehfalle gemäss Dok: 20390489 markiert. * Drehfalle ersetzt. IBS erfolgreich.'}]
# [{'date_time': '17.09.2024 09:18:21', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> ... * * Lokalisierung (Störungsursache): * Türe 1 * * Symptom (Störungsbild): * gestört - ZEITWEISE * *'}, {'date_time': '17.09.2024 09:18:22', 'comment': '* ET1: öffnet nicht - abgetrennt *'}, {'date_time': '28.09.2024 03:19:14', 'comment': '* Ausfallart (Störungsursache): * spricht nicht an * * System BHM 1 (Störungsursache): * Einstiegstüre * * Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Einstiegstüre * *'}, {'date_time': '28.09.2024 03:23:07', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türantrieb elektr. --> Motor zu * Türantrieb *'}]
# [{'date_time': '14.09.2024 06:23:11', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türsteuerung lokal --> Türrechner * * Lokalisierung (Störungsursache): * Türe 3 * * Symptom (Störungsbild): * Störungsanzeige aktiv * * Sofortmassnahme: * Abgetrennt/abgesperrt * *'}, {'date_time': '14.09.2024 06:23:12', 'comment': '* Abgetrennt vorgefunden *'}, {'date_time': '19.09.2024 02:34:03', 'comment': '* Ausfallart (Störungsursache): * Fehler Datenkommunikation * * System BHM 1 (Störungsursache): * Türrechner * * Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Türrechner * * Behebungsmassnahme 2 (Störungsursache): * eingestellt / justiert * * System BHM 3 (Störungsursache): * Türrechner * * Behebungsmassnahme 3 (Störungsursache): * geprüft gem. Checkliste * *'}, {'date_time': '19.09.2024 02:34:06', 'comment': '* Mit UH PC Fehlerspeicher kontrolliert. Fehler Verriegelungsschalter div. * Male aufgetreten. * Primärdrehfalle getauscht und Verriegelungsstange eingestellt, da kein * Spiel vorhanden war. * IBS nach Vorgabe durchgeführt und Protokoll sowie Prüfnummer Drehmoment * angehängt'}]
# [{'date_time': '13.09.2024 21:30:31', 'comment': '* System (Störungsursache): * Innenausbau & Inneneinrichtung --> Innentüren --> Innentüre Fahrgastraum * / Abteiltüre / Trennung 1./2. Klasse --> Türantrieb elektr. * * Lokalisierung (Störungsursache): * Wagenende/Fahrzeugende 2 innen * * Symptom (Störungsbild): * abgenutzt * *'}, {'date_time': '13.09.2024 21:30:32', 'comment': '* Streift beim öffnen bzw. schliessen. *'}, {'date_time': '16.09.2024 14:27:12', 'comment': '* System (Störungsursache): * Kupplung & Fahrzeugübergang --> Wagenübergangstüre / Brandschutzschott * --> Türsteuerung Übergangstüre --> Türrechner * * Lokalisierung (Störungsursache): * Wagenende/Fahrzeugende 1 innen * * Ausfallart (Störungsursache): * übrige Störungen * * System BHM 1 (Störungsursache): * Türrechner * *'}, {'date_time': '16.09.2024 14:27:12', 'comment': '* Türführung gereinigt, Türe Streift nicht mehr. * Fehlermeldung E3A= Inkremente defekt (sehe Bild). * Verkabelung vom Motor angesehen, nichts auffälliges feststellen können. * Türrehner ausgekreuzt ,Fehler ist gewandert. * Türrechner nicht auf Lager. * E-Mail an MVS gemacht. * Materialnummer: 94-001-3454A * Nächste UH Rechner tauschen. *'}, {'date_time': '27.09.2024 14:08:50', 'comment': '* Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Türrechner * * Behebungsmassnahme 2 (Störungsursache): * Update / Upgrade aufgespielt * * System BHM 3 (Störungsursache): * Türrechner * * Behebungsmassnahme 3 (Störungsursache): * geprüft gem. Checkliste * *'}, {'date_time': '27.09.2024 14:08:50', 'comment': '* Türrechner getauscht, SW aktualisiert, Referenzfahrt/Messfahrt * durchgeführt und Baudrate auf 9600 angepasst. * Simulation durchgeführt, Tür läuft wieder einwandfrei und gleichmässig * mit anderer ÜT.'}]
# [{'date_time': '18.08.2024 13:41:57', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türsteuerung lokal --> Türrechner * * Lokalisierung (Störungsursache): * Türe 2 * * Symptom (Störungsbild): * schliesst nicht * * Sofortmassnahme: * Abgetrennt und gegen Wiederinbetriebnahme gesichert * *'}, {'date_time': '18.08.2024 13:41:58', 'comment': '* Türe wurde abgetrennt vorgerfunden *'}, {'date_time': '28.08.2024 10:56:23', 'comment': '* Ausfallart (Störungsursache): * spricht unbegründet an * * System BHM 1 (Störungsursache): * Türrechner * * Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Türrechner * *'}, {'date_time': '28.08.2024 10:56:23', 'comment': '* Türe kontrolliert und festgestellt das der S-Schalter innen in Stellung * öffnen Blockiert war. * An der der Tür 1 auch das selbe. An der Türe 1 und 2 S-Schalter innen * ersetzt. i.O'}]
# [{'date_time': '14.08.2024 22:07:53', 'comment': '* Système (Cause): * Attelage et plaque d’intercirculation --> Porte de plaque * d’intercirculation/cloison coupe-feu --> Entraînement électrique de * porte * * Localisation (Cause): * 5 * * Détail localisation: * MT5 * * Symptôme (Image): * bloqué * *'}, {'date_time': '14.08.2024 22:07:54', 'comment': "* LS75D: * Diagnostic: * - Constaté porte intercirculation MT5 ne s'ouvre pas, constaté défaut * incrémentation, après reset et course de référence, en ordre *  la porte fonctionne. * - Constaté un antécédent le 20.06.2024, moteur a été remplacé pour la * même cause de dérangement. * Réparation nécessaire: * - à contrôle durant 5 jours si le défaut revient. *"}, {'date_time': '23.08.2024 13:04:54', 'comment': '* Genre de panne (Cause): * autres perturbations * * : * Moteur de l’entraînement de porte * *'}, {'date_time': '23.08.2024 13:04:54', 'comment': '* - Repris le diag sur la MT5 * - Plusieurs dérangement en historique --> moteur déjà remplacé * - Remplacé le calculateur, chargé soft 1.05 * - Réglé la course de la porte * - Contrôlé fonctionnement de la porte intercirculation --> OK * - Laissé avis en P23, sous 15j * UHR_LOPEZ *'}, {'date_time': '01.09.2024 15:26:33', 'comment': '* Behebungsmassnahme 1 (Störungsursache): * ersetzt * *System BHM 2 (Störungsursache): * Motor zu Türantrieb * *'}, {'date_time': '01.09.2024 15:26:34', 'comment': "* Controllé il y a plus d'erreurs e.o. *"}, {'date_time': '01.09.2024 15:45:52', 'comment': '* En traversant a la fin * La porte etais de noubeau en panne *'}, {'date_time': '08.09.2024 15:26:51', 'comment': "* Trouver porte défectueux * Contrôler avec UHPC et porte remis en service * Je pense que c'est le calculateur qui est défectueux * A voir au prochain passage si le défaut reviens * Sinon faudra changer le calculateur avec une autre porte voir si le * défaut se déplace * A suivre... *"}, {'date_time': '12.09.2024 16:02:21', 'comment': "* GE75D: * Constaté porte MT5 hors service de nouveau aujourd'hui * Effectué reset sans succès * Réparation necessaire: * Contrôler calculateur *"}, {'date_time': '17.09.2024 01:49:26', 'comment': '* GE75D: * Effectué reset du calculateur de la porte + plusieurs essais, * fonctionnement en ordre ce jour * Remarque: * A suivre *'}, {'date_time': '17.09.2024 08:41:43', 'comment': "* GE75D * Diagnostic : * - Porte à nouveau en dérangement. La porte n'ouvre pas. * Réparation effectuée : * - Fait reset du calculateur sans succès ; la porte s'ouvre à moitié puis * ne s'ouvre plus. * - Fait un reset de la porte en position ouverte et essais ; en ordre * pour le moment. * Réparation nécessaire : * - Calculateur à contrôler. *"}, {'date_time': '21.09.2024 15:50:06', 'comment': "* - sur la porte MT5 MW4 --> le calculateur et moteur ont déjà été * remplacé * - Contrôlé le câble dans la gaine anaconda --> R.A.S ( l'alimentation * des boutons) * - Pour avancé le diag --> voulu permuté le calculateur entre MT5 et MT6 * --> NOK, lorsque les 2 calculateurs ont été permuté, * aucune portes fonctionnaient. * - Remis le calculateur sur la MT6 * - Remplacé le calculateur de la MT5 et chargé soft 1.05 * - Remplacé aussi le moteur de la MT5 * - Réglé la course de la porte e.o. * - Je laisse l'avis ouvert sous 15j * En attente * UHR_LOPEZ *"}, {'date_time': '27.09.2024 12:17:43', 'comment': '* - Constaté en arrivant sur la rame, porte MT5 MW4 en dérangement " * incrémentation H.S" * - Chargé à nouveau le soft en sélectionnant porte MT5 sur l\'UHPC * - Contrôlé les fonctions de la porte avec le programme --> R.A.S * - Contrôlé le câblage du calculateur au moteur --> constaté connecteur * X4 mal fixé * - Connecté correctement * - Essayé de bouger les câbles lors de l\'ouverture / fermeture -> R.A.S * - Laissé l\'avis ouvert pendant 15j, a suivre * UHR_LOPEZ *'}, {'date_time': '28.09.2024 12:47:08', 'comment': '* contrôler ce jours pas constater de dérangements porte fonctionnelle  a * suivre sous 14j *'}, {'date_time': '30.09 ...
# [{'date_time': '08.08.2024 00:35:41', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> ... * * Lokalisierung (Störungsursache): * Türe 1 * * Symptom (Störungsbild): * gestört - ZEITWEISE * * Ausfallart (Störungsursache): * fehlt * * System BHM 1 (Störungsursache): * Einstiegstüre * *'}, {'date_time': '08.08.2024 00:35:42', 'comment': '* Bei T002 festgestellt: Tür 1 abgetrennt. DDS Nr. 17025 *'}, {'date_time': '08.08.2024 03:21:48', 'comment': '* Behebungsmassnahme 1 (Störungsursache): * Test / Simulation durchgeführt * * System BHM 2 (Störungsursache): * Einstiegstüre * *'}, {'date_time': '08.08.2024 03:21:51', 'comment': '* UH-PC angehängt zum Fehlerspeicher auszulesen. * Fehlermeldung : Maximale Anzahl Schliessungs Versuche überschritten, * dauerhaft anstehend. * Im Fehlerspeicher ist diese Meldung nicht zu sehen Fehler kann auch * nicht quittiert werden. * Türe Mechanisch Geprüft --> Bei der Primärdrehfalle ist der * Verriegelungs-Kontrollschalter verklemmt dieser ist dauerbetätigt. * Der Endschalter konnte wieder gängig  gemacht werden jedoch verklemmt * dieser immer wieder. * Türe wieder sicher verriegelt (Übertotlage ist gegeben) und abgetrennt. * Dazugehörige Massnahme erstellt. * ------------------------ * Im nächstem UH bitte Primärdrehfalle tauschen. Artikelnummer * 94-000-1950A / Lagerort 02-01-B/R *'}, {'date_time': '25.08.2024 13:30:59', 'comment': '* Primärdrehfalle wurde ersetzt. IBS-Protokoll durchgeführt i.o'}]
# [{'date_time': '01.08.2024 07:39:06', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> ... * * Lokalisierung (Störungsursache): * Türe 1 * * Symptom (Störungsbild): * öffnet nicht * *'}, {'date_time': '01.08.2024 07:39:07', 'comment': '* - Einstiegstüre MT41 öffnet nicht über Öffnungstaster innen wie aussen * - Bhf LS * - Einstiegstüre verriegelt und gekennzeichnet *'}, {'date_time': '01.08.2024 13:37:12', 'comment': "* LS75D * - Constaté multitude de défaut sur cette porte , suite a simulation avec * le PC , constaté que le marche pied ne sort pas . * Effectué un reset de la porte et plusieurs essais en ordre . * - Quand j'ai voulu faire les essais depuis la cabine , la porte c'est * remise en défaut - senseur marche pied . * - Porte verrouillée et cartée * Réparation nécessaire : * - A contrôler lors d'un arrêt prolongé . *"}, {'date_time': '19.08.2024 12:40:32', 'comment': '* Genre de panne (Cause): * ne répond pas * * : * Porte d’accès * *'}, {'date_time': '19.08.2024 12:40:35', 'comment': '* - Normalisé porte 41, pas défaut apparent * - Connecté l\'UHPC, constaté des défauts sporadiques qui durent 1 sec * - "défaut relai K2, défaut de tension" * - Remplacé le calculateur, contrôlé soft 1.14 * - Contrôlé fonctionnement de la porte --> e.o. * - Plus d\'erreur sporadique, e.o.* Porte remis en service * UHR_LOPEZ *'}, {'date_time': '19.08.2024 12:40:59', 'comment': '* Mesure de réparation 1 (Cause): * remplacé * * : * Porte d’accès *'}]
# [{'date_time': '25.07.2024 08:46:52', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> ... * * Lokalisierung (Störungsursache): * Türe 2 * * Symptom (Störungsbild): * schliesst nicht * * Sofortmassnahme: * Abgetrennt/abgesperrt * *'}, {'date_time': '25.07.2024 08:46:53', 'comment': '* Tür schliesst nicht. Abgetrennt *'}, {'date_time': '12.08.2024 16:01:04', 'comment': '* Ausfallart (Störungsursache): * abgebrochen / zerbrochen / abgerissen * * System BHM 1 (Störungsursache): * Einstiegstüre * * Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Einstiegstüre * * Behebungsmassnahme 2 (Störungsursache): * geprüft gem. Checkliste * * System BHM 3 (Störungsursache): * Einstiegstüre * *'}, {'date_time': '12.08.2024 16:01:07', 'comment': '* Beim Anschliessen des UH PCs bzw. Öffnen der Deckenklappe ist ein Teil * des Verriegelungskontrollschalters runtergefallen. * Primärdrehfalle getauscht und IBS nach Vorgabe durchgeführt'}]
# [{'date_time': '23.07.2024 06:08:19', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Schiebetritt --> Schiebetrittantrieb elektr. * * Lokalisierung (Störungsursache): * Türe 2 * * Symptom (Störungsbild): * fährt nicht ein * * Sofortmassnahme: * Abgetrennt/abgesperrt * *'}, {'date_time': '23.07.2024 06:08:20', 'comment': '* Türe 02 abgetrennt Schiebetritt fährt nicht ein *'}, {'date_time': '31.07.2024 03:13:17', 'comment': '* Ausfallart (Störungsursache): * startet nicht / lässt sich nicht einschalten * * System BHM 1 (Störungsursache): * Schiebetrittantrieb elektr. * * Behebungsmassnahme 1 (Störungsursache): * Messwert(e) ausgelesen / erfasst * * System BHM 2 (Störungsursache): * Schiebetrittantrieb elektr. * * Behebungsmassnahme 2 (Störungsursache): * ersetzt * * System BHM 3 (Störungsursache): * Schiebetrittantrieb elektr. * * Behebungsmassnahme 3 (Störungsursache): * geprüft gem. Checkliste * *'}, {'date_time': '31.07.2024 03:13:19', 'comment': '* Zuerst Schiebetritt kontrolliert. Mit UH PC und in ausgeschaltetem * Zustand keine Abweichungen festgestellt. Schiebetritt läuft * sehr leichtgängig. * Türe zeigt Fehler Verriegelungsschalter. Nur 1x anstehend gewesen. Neue * Drehfalle elektrisch angeschlossen und Simulation * durchgeführt, Tür läuft normal. * Primärdrehfalle getauscht und IBS nach Vorgabe durchgeführt. Protokoll * und Prüfnummer Drehmomentschlüssel angehängt'}]
# [{'date_time': '20.07.2024 15:41:38', 'comment': '* System (Störungsursache): * Kupplung & Fahrzeugübergang --> Wagenübergangstüre / Brandschutzschott * --> ... * * Lokalisierung (Störungsursache): * Zwischendeck WE1 * * Symptom (Störungsbild): * öffnet nicht * *'}, {'date_time': '20.07.2024 15:41:39', 'comment': '* Repair&Clean Mailer * +++++++++++++++++++++++ * Wagenübergangstüre; Öffnet nicht automatisch * * Erstintervention * - Welche Übergangstüre ist betroffen? * > Zwischendeck Seite 1 (MT5) * - Ist die Brandschutzfunktion der Übergangstüre noch vorhanden? * > Ja, Übergangstüre schliesst vollständig, muss einfach von Hand * geöffnet werden und schliesst danach wieder korrekt. * - Ist die benachbarte Übergangstüre in Betrieb? * > Ja, Übergangstüre normal in Betrieb. * * Zusätzliche Beschreibung * nur noch manueller betrieb möglich * *'}, {'date_time': '12.08.2024 02:19:06', 'comment': '* Ausfallart (Störungsursache): * übrige Störungen * * System BHM 1 (Störungsursache): * Wagenübergangstüre / Brandschutzschott * *'}, {'date_time': '12.08.2024 02:19:06', 'comment': '* Inkrementalgeber defekt, laut Türrechner. Motor getauscht, Fehler * bleibt. Aufgefallen, dass die Litzen des Inkrementalgebers * vertauscht angeschlossen sind. Litzen nach Beschriftung angeschlossen, * Fehler bleibt. Motor wieder rückgetauscht. Türverschalung * demontiert um alle Stecker und Litzen zu überprüfen, i.O. * Türrechner getauscht, SW geladen. * Fehler weg, aber Inkrementalgeber zählt rückwärts. Festgestellt, dass im * Schema grün und gelb das Inkrementalgebers vertauscht * sind, dass heisst, die Litzen sind verkehrt beschriftet. Schema für * Abteiltür geholt und gesehen, dass da grün und gelb nach * Beschriftung stimmen. * Da eine Seite der Abteiltür den gleichen Motor hat, wie die * Übergangstür, ist das etwas verwirrend. * Litzen nach Schema angeschlossen, Mess/Referenzfahrt ausgeführt, i.O. *'}, {'date_time': '12.08.2024 02:20:32', 'comment': '* Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Wagenübergangstüre / Brandschutzschott * *'}, {'date_time': '12.08.2024 02:20:32', 'comment': '* Ini zum Abtrennen der Tür gerichtet und eingestellt.'}]
# [{'date_time': '11.07.2024 14:35:12', 'comment': '* Système (Cause): * Systèmes d’accès --> Porte d’accès --> Commande des portes, locale --> * Calculateur de porte * * Localisation (Cause): * Porte 4 * * Symptôme (Image): * déclenché * * Genre de panne (Cause): * démarre pas / ne se laisse pas enclencher * * : * Calculateur de porte * *'}, {'date_time': '11.07.2024 15:44:16', 'comment': "* Trouvé porte carté * Constaté error qui viens sporadiquement. Quand la porte se ouvre et se * ferme. On a l'impression que c'est le calculateur. * On l'a changé. * Maitenant l'error ne reviens plus, * Par contre pas reuçi de charger la soft. A faire au prochaine paasage *"}, {'date_time': '16.07.2024 09:53:31', 'comment': '* Mesure de réparation 1 (Cause): * mise à jour effectuée * * : * Calculateur de porte * *'}, {'date_time': '16.07.2024 09:53:32', 'comment': '* Soft charge ce jour * E.O après chargement * UHR GUILLAUME'}]
# [{'date_time': '03.07.2024 14:43:02', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Führungselement * --> ... * * Lokalisierung (Störungsursache): * Türe 3 * * Symptom (Störungsbild): * lose * *'}, {'date_time': '03.07.2024 14:41:46', 'comment': '* An dieser Einstiegstür müssen alle Befestigungsschrauben der Führungsschiene beider Linearführungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben „Flachkopf-TORX-Schraube M6x8 mit Tuflok" 94-003-1630 müssen einzeln getauscht werden und gemäss BBA 20398308, mit 9.5 Nm angezogen werden und sind entweder im Türgitterschrank oder unter dem Lagerplatz 0600 Pünten Magazin AK-34-19-1 zu finden. *'}, {'date_time': '03.07.2024 09:30:33', 'comment': '* Symptom (Störungsbild): * lose *'}, {'date_time': '14.08.2024 14:42:48', 'comment': '* Ausfallart (Störungsursache): * abgebrochen / zerbrochen / abgerissen * * System BHM 1 (Störungsursache): * Führungselement * *'}, {'date_time': '14.08.2024 14:42:50', 'comment': '* Schrauben einzeln getauscht der unteren Linearführung. Bei der oberen * Linearführung sind 2 Schrauben abgerissen ohne den * geringsten Kraftaufwand. Linearführung ausgebaut und versucht, die * Schrauben aus der Gleitschiene auszubauen. Mit kleiner Flex 2 * Schlitze gefräst und mit Heissluftföhn und Schlitzschraubendreher * versucht, Schrauben auszubauen, ohne Erfolg. * Mit Bohrer und Linksdrall konnten die Schrauben entfernt werden. * Linearführung getauscht und IBS nach Vorgabe durchgeführt. * Linkes Türblatt eingestellt, da Parallelität nicht stimmte sowie die * Fanghaken des linken Tür. 5 Schrauben des Türblattes ersetzt, * mit 27Nm angezogen und markiert. * IBS Protokoll,Schliesskraftmessprotokoll sowie Prüfnummern der * Drehmomentschlüssel der Meldung angehängt. *'}, {'date_time': '14.08.2024 14:43:58', 'comment': '* Behebungsmassnahme 1 (Störungsursache): * Fremdkörper entfernt * * System BHM 2 (Störungsursache): * Führungselement * * Behebungsmassnahme 2 (Störungsursache): * ersetzt * * System BHM 3 (Störungsursache): * Führungselement * * Behebungsmassnahme 3 (Störungsursache): * eingestellt / justiert *'}]
# [{'date_time': '03.07.2024 18:04:48', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> ... * * Lokalisierung (Störungsursache): * Türe 2 * * Symptom (Störungsbild): * schliesst nicht * * Sofortmassnahme: * Abgetrennt und gegen Wiederinbetriebnahme gesichert * *'}, {'date_time': '03.07.2024 18:04:51', 'comment': '* Tür durch LF abgetrennt (schliesst nicht). *'}, {'date_time': '11.07.2024 15:17:10', 'comment': '* Ausfallart (Störungsursache): * abgebrochen / zerbrochen / abgerissen * * System BHM 1 (Störungsursache): * Einstiegstüre * * Behebungsmassnahme 1 (Störungsursache): * Messwert(e) ausgelesen / erfasst * * System BHM 2 (Störungsursache): * Einstiegstüre * * Behebungsmassnahme 2 (Störungsursache): * ersetzt * * System BHM 3 (Störungsursache): * Einstiegstüre * * Behebungsmassnahme 3 (Störungsursache): * geprüft gem. Checkliste * *'}, {'date_time': '11.07.2024 15:17:13', 'comment': '* Mit UH PC Messwerte, Fehlerspeicher und Motorstromkurven kontrolliert. * Auffällig ist, das 54x Schiebetrittbelastung aufgetreten * ist. Schiebetritt läuft normal und keine Geräuschbildung hörbar. * Türsystem freigegeben und Simulation durchgeführt. Tür öffnet normal * aber in geschlossenem Zustand versucht die Tür weiterhin noch * mehr zu schliessen und geht dann in Störung.* Türsystem ausgeschaltet und Primärdrehfalle kontrolliert. Betätigungsarm * des Schnappschalters der Drehfalle gebrochen, daher * Drehfalle komplett getauscht und IBS nach Vorgabe durchgeführt. * IBS Protokoll, Schliesskraftprotokoll und Drehmomentprüfnummer der * Meldung angehängt. * Tür läuft wieder einwandfrei und die Übertotpunktlage ist I.O.'}]
# [{'date_time': '03.07.2024 09:36:27', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Führungselement * --> ... * * Lokalisierung (Störungsursache): * Türe 1 * * Symptom (Störungsbild): * lose * *'}, {'date_time': '03.07.2024 09:34:49', 'comment': '* An dieser Einstiegstür müssen alle Befestigungsschrauben der Führungsschiene beider Linearführungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben „Flachkopf-TORX-Schraube M6x8 mit Tuflok" 94-003-1630 müssen einzeln getauscht werden und gemäss BBA 20398308, mit 9.5 Nm angezogen werden und sind entweder im Türgitterschrank oder unter dem Lagerplatz 0600 Pünten Magazin AK-34-19-1 zu finden. *'}, {'date_time': '03.07.2024 09:30:33', 'comment': '* Symptom (Störungsbild): * lose *'}]
# [{'date_time': '03.07.2024 09:40:58', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Führungselement * --> ... * * Lokalisierung (Störungsursache): * Türe 3 * * Symptom (Störungsbild): * lose * *'}, {'date_time': '03.07.2024 09:39:17', 'comment': '* An dieser Einstiegstür müssen alle Befestigungsschrauben der   Führungsschiene beider Linearführungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben „Flachkopf-TORX-Schraube M6x8 mit Tuflok" 94-003-1630   müssen einzeln getauscht werden und gemäss BBA 20398308, mit 9.5 Nm   angezogen werden und sind entweder im Türgitterschrank oder unter dem   Lagerplatz 0600 Pünten Magazin AK-34-19-1 zu finden. *'}, {'date_time': '03.07.2024 09:30:33', 'comment': '* Symptom (Störungsbild): * lose *'}, {'date_time': '12.07.2024 10:15:50', 'comment': '* Ausfallart (Störungsursache): * falsches Bauteil eingebaut * * System BHM 1 (Störungsursache): * Führungselement * * Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Führungselement * * Behebungsmassnahme 2 (Störungsursache): * festgezogen * * System BHM 3 (Störungsursache): * Führungselement * *'}, {'date_time': '12.07.2024 10:15:53', 'comment': '* Alle Schrauben einzeln getauscht und mit 9.5Nm angezogen. Prüfnummer * Drehmomentschlüssel im Anhang'}]
# [{'date_time': '03.07.2024 09:46:53', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Führungselement * --> ... * * Lokalisierung (Störungsursache): * Türe 1 * * Symptom (Störungsbild): * lose * *'}, {'date_time': '03.07.2024 09:45:38', 'comment': '* An dieser Einstiegstür müssen alle Befestigungsschrauben der   Führungsschiene beider Linearführungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben „Flachkopf-TORX-Schraube M6x8 mit Tuflok" 94-003-1630   müssen einzeln getauscht werden und gemäss BBA 20398308, mit 9.5 Nm   angezogen werden und sind entweder im Türgitterschrank oder unter dem   Lagerplatz 0600 Pünten Magazin AK-34-19-1 zu finden. *'}, {'date_time': '03.07.2024 09:30:33', 'comment': '* Symptom (Störungsbild): * lose *'}, {'date_time': '09.07.2024 10:44:04', 'comment': '* Ausfallart (Störungsursache): * falsches Bauteil eingebaut * * System BHM 1 (Störungsursache): * Führungselement * * Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Führungselement * * Behebungsmassnahme 2 (Störungsursache): * festgezogen * * System BHM 3 (Störungsursache): * Führungselement * *'}, {'date_time': '09.07.2024 10:44:07', 'comment': '* Alle 30 Schrauben einzeln ersetzt und mit 9.5Nm angezogen'}]
# [{'date_time': '03.07.2024 14:41:32', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Führungselement * --> ... * * Lokalisierung (Störungsursache): * Türe 1 * * Symptom (Störungsbild): * lose * *'}, {'date_time': '03.07.2024 14:40:21', 'comment': '* An dieser Einstiegstür müssen alle Befestigungsschrauben der   Führungsschiene beider Linearführungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben „Flachkopf-TORX-Schraube M6x8 mit Tuflok" 94-003-1630   müssen einzeln getauscht werden und gemäss BBA 20398308, mit 9.5 Nm   angezogen werden und sind entweder im Türgitterschrank oder unter dem   Lagerplatz 0600 Pünten Magazin AK-34-19-1 zu finden. *'}, {'date_time': '03.07.2024 09:30:33', 'comment': '* Symptom (Störungsbild): * lose *'}]
# [{'date_time': '03.07.2024 14:38:27', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Führungselement * --> ... * * Lokalisierung (Störungsursache): * Türe 1 * * Symptom (Störungsbild): * lose * *'}, {'date_time': '03.07.2024 14:36:41', 'comment': '* An dieser Einstiegstür müssen alle Befestigungsschrauben der   Führungsschiene beider Linearführungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben „Flachkopf-TORX-Schraube M6x8 mit Tuflok" 94-003-1630   müssen einzeln getauscht werden und gemäss BBA 20398308, mit 9.5 Nm   angezogen werden und sind entweder im Türgitterschrank oder unter dem   Lagerplatz 0600 Pünten Magazin AK-34-19-1 zu finden. *'}, {'date_time': '03.07.2024 09:30:33', 'comment': '* Symptom (Störungsbild): * lose *'}]
# [{'date_time': '02.07.2024 08:39:34', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Führungselement * --> ... * * Lokalisierung (Störungsursache): * Türe 3 * *'}, {'date_time': '02.07.2024 08:38:12', 'comment': '* An dieser Einstiegstür müssen alle Befestigungsschrauben der   Führungsschiene beider Linearführungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben „Flachkopf-TORX-Schraube M6x8 mit Tuflok" 94-003-1630   müssen einzeln getauscht werden und gemäss BBA 20398308, mit 9.5 Nm   angezogen werden und sind entweder im Türgitterschrank oder unter dem   Lagerplatz 0600 Pünten Magazin AK-34-19-1 zu finden. *'}, {'date_time': '03.07.2024 09:30:51', 'comment': '* Symptom (Störungsbild): * lose * *'}]
# [{'date_time': '02.07.2024 08:34:01', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Führungselement * --> ... * * Lokalisierung (Störungsursache): * Türe 2 * *'}, {'date_time': '02.07.2024 08:31:10', 'comment': '* An dieser Einstiegstür müssen alle Befestigungsschrauben der   Führungsschiene beider Linearführungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben „Flachkopf-TORX-Schraube M6x8 mit Tuflok" 94-003-1630   müssen einzeln getauscht werden und gemäss BBA 20398308, mit 9.5 Nm   angezogen werden und sind entweder im Türgitterschrank oder unter dem   Lagerplatz 0600 Pünten Magazin AK-34-19-1 zu finden. *'}, {'date_time': '03.07.2024 09:32:00', 'comment': '* Symptom (Störungsbild): * lose * *'}, {'date_time': '04.09.2024 12:45:11', 'comment': '* Ausfallart (Störungsursache): * verschlissen / abgenutzt * * System BHM 1 (Störungsursache): * Führungselement * * Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Führungselement * *'}, {'date_time': '04.09.2024 12:45:14', 'comment': '* Schrauben ersetzt * funktionskontrolle tür i.o'}]
# [{'date_time': '23.06.2024 22:26:05', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türblatt / Türflügel komplett --> * ... * * Lokalisierung (Störungsursache): * Türe 2 * * Symptom (Störungsbild): * falsches Bauteil verbaut * * Ausfallart (Störungsursache): * falsches Bauteil eingebaut * * System BHM 1 (Störungsursache): * Türblatt / Türflügel komplett * *'}, {'date_time': '23.06.2024 22:26:06', 'comment': '* Festgestellt dass das falsche Türblatt montiert ist, mit blauer * Rollstuhlfahrer Taste (siehe Bild). Abklärung mit PDT was dort * gemacht wird. *'}, {'date_time': '26.06.2024 13:23:47', 'comment': '* Bitte das falsche Türblatt mit Rollstuhltaster auswechseln und das   korrekte Türblatt 717-27-101A einbauen, Artikel wurde bestellt. * Bitte das ausgebaute Türblatt begutachten ob es in einem guten Zustand   ist -> als A-Artikel 717-27-102A einlagern lassen, oder ob es   Beschädigungen hat und wir es als D-Material 717-27-102A zurückschicken.   Für die Entscheidung kann PDT dazugeholt werden. *'}, {'date_time': '15.07.2024 03:12:10', 'comment': '* Mass: Türblatt ersetzt. * Neues Türblatt kann nicht eingestellt werden. * Türblatt im Bereich des Fanghackens nach innen verzogen. * Masse oder Verriegelungskraft ausser Toleranz, je nach Einstellung. * Nochmal Türblatt bestellt. *Erw.Mass: Türblatt erneut ersetzen. * 4x Befestigungsschrauben der linken Drehsäule in den Wagenkasten * einstellen/ersetzen. *'}, {'date_time': '03.08.2024 07:36:34', 'comment': '* - Türe abgeschlossen und gekennzeichnet vorgefunden Grund unbekannt *'}, {'date_time': '03.08.2024 12:54:04', 'comment': '* ZUE75D: * Türe auf korrekten Verschluss geprüft. * Grünschlaufe vorhanden. *'}, {'date_time': '30.09.2024 01:36:55', 'comment': '* Diag: Einlaufwinkel des anderen Türblattes steht schon an während * schliessen. * Darum wirkte die andere Tür verzogen und die Verriegelungskraft war zu * hoch. * Mass: Einlaufwinkel eingestellt. * IBS erfolgreich. * Bestelltes Türblatt im Magazin abgegeben. *'}, {'date_time': '30.09.2024 01:37:08', 'comment': '* Behebungsmassnahme 1 (Störungsursache): * Reset / Neustart durchgeführt * * System BHM 2 (Störungsursache): * Türblatt / Türflügel komplett *'}]
# [{'date_time': '21.06.2024 07:48:53', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Türsteuerung & -bedienung Zugebene --> ... * * Lokalisierung (Störungsursache): * Türe 4 * * Symptom (Störungsbild): * gestört - ZEITWEISE * *'}, {'date_time': '21.06.2024 07:48:54', 'comment': '* Tür schliesst nur mut Zwangsschliessung *'}, {'date_time': '02.07.2024 02:09:02', 'comment': '* Ausfallart (Störungsursache): * Fehler Datenkommunikation * * System BHM 1 (Störungsursache): * Türsteuerung & -bedienung Zugebene * * Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Türsteuerung & -bedienung Zugebene * *'}, {'date_time': '02.07.2024 02:09:02', 'comment': '* Türe kontrolliert und festgestellt das der Sender der Empfänger der * Lichtschranke defekt ist. * Diesen ersetzt geprüft io'}]
# [{'date_time': '19.06.2024 11:42:03', 'comment': '* Système (Cause): * Systèmes d’accès --> Porte d’accès --> Mécanisme de porte --> Unité de * verrouillage/déverrouillage * * Localisation (Cause): * Porte 2 * * Symptôme (Image): * bloqué * * Genre de panne (Cause): * mal connecté * * : * Unité de verrouillage/déverrouillage * *'}, {'date_time': '19.06.2024 11:42:05', 'comment': "* A l'arrivée sur le train constaté porte MT22 carté * Après analyse constaté capteur porte fermée HS (selon ordre BODE * interdit de remplacer capteur seul) * Verrouillage primaire a remplacer au prochain passage * UHR GUILLAUME ANDREETTI *"}, {'date_time': '26.06.2024 16:14:21', 'comment': "* J'ai chsnge le verouillage primaire. * Après la porte etias tjr en panne. * A suivre *"}, {'date_time': '26.06.2024 16:22:57', 'comment': '* il affiche une dds dans la cabine un erreur de liberation. * pas pû poursuivre plus. * *'}, {'date_time': '26.07.2024 15:43:14', 'comment': '* Mesure de réparation 1 (Cause): * remplacé * * : * Unité de verrouillage/déverrouillage * *'}, {'date_time': '26.07.2024 15:43:14', 'comment': "* - Repris le diag sur la porte MT22 * - Constaté connecteur mal fixé sur le calculateur, par conséquent la * porte ne se fermait pas. * - Effectué protocole suite au remplacement du verrouillage primaire + * joint à l'avis * - Suite au protocole, constaté les poignées d'urgence hors tolérance * - Ouvert un autre avis pour cela * - Porte MT22 e.o. * UHR_LOPEZ_MOUGIN_ANDREETTI"}]
# [{'date_time': '31.05.2024 19:22:11', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türsteuerung lokal --> Türrechner * * Lokalisierung (Störungsursache): * Türe 4 * * Symptom (Störungsbild): * Störungsanzeige aktiv * *'}, {'date_time': '31.05.2024 19:22:12', 'comment': '* DDS 15142. *'}, {'date_time': '03.06.2024 16:06:28', 'comment': '* Ausfallart (Störungsursache): * elektrische Leistungswerte ausserhalb Toleranz * * System BHM 1 (Störungsursache): * Türrechner * * Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Türrechner * * Behebungsmassnahme 2 (Störungsursache): * Update / Upgrade aufgespielt * * System BHM 3 (Störungsursache): * Türrechner * * Behebungsmassnahme 3 (Störungsursache): * geprüft gem. Checkliste * *'}, {'date_time': '03.06.2024 16:06:29', 'comment': '* Abgetrennte Tür freigegeben und Simulation durchgeführt. Türe knallt * voller Wucht auf und zu. UH PC angehängt und Ein-/Ausgänge * sowie Fehlerspeicher kontrolliert. Fehler Motor/Weggeber. Wendelkabel * auf Beschädigung und Abbrand oder Defekt der Pins * kontrolliert, keine Abweichungen festgestellt. Bei Klemme X99 alle * Stecker auf korrekten Steckplatz kontrolliert, keine * Abweichungen festgestellt. * Winkelgetriebeeinheit getauscht aber keine Verbesserung. Türrechner * getauscht und SW geladen, ebenfalls keine Verbesserung. * Weisser Leitungsstrang im Türantrieb auf Kabelbruch oder Beschädigungen * kontrolliert, keine Abweichungen festgestellt. Das * Wendelkabel ausgebaut und ohmisch jede Leitung gemessen, 2 Leitungen * haben Unterbruch, aber auf beiden Anschlussseiten kein Defekt * festgestellt, daher müsste im Wendelkabel selber ein Kabelbruch * vorliegen ohne das dieser ersichtlich war. Wendelkabel getauscht * und Funktionskontrolle durchgeführt,Tür läuft wieder einwandfrei. * IBS Protokoll nach Vorgabe für "Tausch Winkelgetriebe", "Tausch * Türrechner" sowie für das "Laden der SW" durchgeführt und * angehängt. Prüfnummer Drehmomentschlüssel und Schliesskraftmessung * ebenfalls der Meldung angehängt'}]
# [{'date_time': '30.05.2024 13:27:30', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türnotöffnung --> mech. * Entriegelung innen * * Lokalisierung (Störungsursache): * Türe 1 * * Symptom (Störungsbild): * ausgelöst * * Ausfallart (Störungsursache): * lose / unzureichend befestigt * * System BHM 1 (Störungsursache): * mech. Entriegelung innen * * Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * mech. Entriegelung innen * *'}, {'date_time': '30.05.2024 13:27:31', 'comment': '* MBS/BIR : Die sekundäre Drehfalle im Tür 1 ist lose , nach MR371 Haben * wir die Drehfalle Gewechselt alles I.O'}]
# [{'date_time': '18.05.2024 16:30:26', 'comment': '* System (Störungsursache): * Kupplung & Fahrzeugübergang --> Wagenübergangstüre / Brandschutzschott * --> ... * * Lokalisierung (Störungsursache): * Keine Lokalisierung notwendig * * Symptom (Störungsbild): * öffnet nicht * *'}, {'date_time': '30.05.2024 00:05:27', 'comment': '* Ausfallart (Störungsursache): * Parameterverlust * * System BHM 1 (Störungsursache): * Wagenübergangstüre / Brandschutzschott * *'}, {'date_time': '30.05.2024 00:05:27', 'comment': '* DDS * 14323 Stirnwandtür 2: Störung * 14325 Stirnwandtür 2: Abgetrennt * Motor oder Inkrementalgeber defekt * Problem wird sein, dass sich die Endanschläge verstellt haben. * Mess/Referenzfahrt ausgeführt, auf neuen Wert parametriert. * Endanschläge im nächsten UH kontrollieren/einstellen. *'}, {'date_time': '07.06.2024 00:56:56', 'comment': '* Motor Verkabelungen kontrolliert. * Endanschläge wurden kontrolliert stehen auf richtige Position. * Mess/Referenzfahrt ausgeführt, auf neuen Wert parametriert. * Im nächsten UH Nachkontrolle falls DDS 14232,14325 wieder auftritt Motor * tauschen. *'}, {'date_time': '11.06.2024 12:30:31', 'comment': '* Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Wagenübergangstüre / Brandschutzschott * *'}, {'date_time': '11.06.2024 12:30:31', 'comment': '* Seit dem 07.06.24 ist DDS 14325 vier mal aufgetreten und 14323 zwei mal * für insgesamt 26h. * -------------------------- * Motor ersetzt. * -------------------------- * Im nächstem UH nochmals Nachkontrolle auf DDS 14325 und 142323. *'}, {'date_time': '19.06.2024 02:43:11', 'comment': '* Behebungsmassnahme 2 (Störungsursache): * Messwert(e) ausgelesen / erfasst * * System BHM 3 (Störungsursache): * Wagenübergangstüre / Brandschutzschott * * Behebungsmassnahme 3 (Störungsursache): * geprüft gem. Checkliste * *'}, {'date_time': '19.06.2024 02:43:11', 'comment': '* DDS 14323 am 13.06 wieder für 23h anstehend gewesen. Bildschirm * ausgebaut und Leitungen Fz.seitig auf korrekte Position * kontrolliert, aber keine Abweichungen festgestellt. Der Rechner war im * Prg Modus, allerdings wird dies nichts mit der Störung zu * tun haben. Auf RUN umgestellt und Referenz-/Messfahrt durchgeführt. * Bitte im nächsten UH einmalige Nachkontrolle auf DDS 14323 *'}, {'date_time': '20.06.2024 16:06:08', 'comment': '* Ist heute von 08:17 bis 08:31 wieder aufgetreten. * Im nächsten UH bitte mal den Rechner mit WE1 auskreuzen. *'}, {'date_time': '26.06.2024 16:07:53', 'comment': '* Haben den Türrechner aufgekreuzt mit dem WE1 als wir den Rechner vom WE2 * auf WE1 montierten ist der Fehler sofort auf dem WE1 * aufgetreten also ist der Rechner defekt und muss ersetzt werden. * Im nächsten UH bitte einen Neuen Rechner montieren *'}, {'date_time': '09.07.2024 03:33:30', 'comment': '* Türrechner ersetzt i.O * Neue Software geladen i.O * Seit dem Tausch ist aber die DDS 13022 aktiv. * Winkelstecker (INTECS) für CAN mit Wagen 400 WE2 gekreuzt --> Störung * weiterhin auf Wagen 300. * ----------------- * In nächstem UH DDS 13022 weiterverfolgen. *'}, {'date_time': '09.07.2024 20:29:21', 'comment': '* Der neue Rechner scheint defekt zu sein, da ursprünglich der Fehler auf   MT6 DDS 13023 war und der Fehler durch auskreuzen mit MT5 auf diese   übertragen ( DDS 13022 ) wurde. Nun wurde dieser Rechner ( MT5 ) gegen   einen neuen getauscht, hat aber den gleichen Fehler. Bitte erneut   tauschen und RNC machen. *'}, {'date_time': '19.07.2024 15:44:25', 'comment': '* Rechner erneut ersetzt und Software geladen --> Neuer Rechner ebenfalls * defekt Türe geht nach einmaliger Betätigung in Manuelen * Betrieb. * Rechner erneut ersetzt und Software geladen, Türe geprüft i.O * -------------- * Im nächstem UH Nachkontrolle auf DDS 13022 *'}, {'date_time': '27.07.2024 03:04:33', 'comment': '* Diag: DDS 13022 erneut 3x aufgetreten, zusätzlich auch DDS 14303 * "Stirnwandtür 1: Störung" * Aus dem Langtext ist nicht ganz klar, Was nun wo neu ist. * Seit d ...
# [{'date_time': '10.05.2024 16:25:26', 'comment': '* System (Störungsursache): * Kupplung & Fahrzeugübergang --> Wagenübergangstüre / Brandschutzschott * --> Türsteuerung Übergangstüre --> ... * * Lokalisierung (Störungsursache): * Wagenende/Fahrzeugende 1 innen * * Symptom (Störungsbild): * öffnet nicht * *'}, {'date_time': '10.05.2024 16:25:27', 'comment': '* Meldung RC-App: * * Melder:in * david.trachsler@sbb.ch * * Objekt; Zustand * Wagenübergangstüre; Blockiert * * Erstintervention * - Welche Übergangstüre ist betroffen? * > Zwischendeck Seite 1 (MT5) * - Ist die Brandschutzfunktion der Übergangstüre noch vorhanden? * > Ja, Übergangstüre in geschlossener Stellung verriegelt und es folgt * ein für Reisende zugängliches Fahrzeug * - Ist die benachbarte Übergangstüre in Betrieb? * > Ja, Übergangstüre normal in Betrieb. * * Zusätzliche Beschreibung * Türe geschlossen, lässt sich nicht öffnen *'}, {'date_time': '10.05.2024 23:38:33', 'comment': '* Localisation (Cause): * Entrepont VE2 * * Genre de panne (Cause): * démarre pas / ne se laisse pas enclencher * *'}, {'date_time': '10.05.2024 23:38:33', 'comment': '* Ls75D: * Diagnostic: * - porte VE1 MT5 RAS, constaté que c\'est la porte VE2 MT6 qui est en * panne. * - constaté que les interrupteurs de porte sont éteint, pas de réaction, * verrouillée et ouvert au carré pas de changement, sur * électronique annoncé "Motor Getrennt" * - Reset l\'électronique mais l\'écran se rallume sans que rien ne * s\'affiche, aucune plus de réaction de l\'écran, coupé avec * l\'interrupteur à côté de l\'électronique et carté la porte. * Réparation nécessaire: * - électronique à remplacer. *'}, {'date_time': '10.05.2024 23:38:34', 'comment': '* : * Commande de la porte d’intercirculation * *'}, {'date_time': '14.05.2024 11:37:55', 'comment': '* Mesure de réparation 1 (Cause): * remplacé * * : * Commande de la porte d’intercirculation * *'}, {'date_time': '14.05.2024 11:37:56', 'comment': "* -Repris le diag sur la porte intercirculation MT6 * - Pas de défaut apparent * - Contrôlé historique, + 40 DDS pour dérangement com sur le calculateur * - Remplacé calculateur + chargé soft 1.05 * - Réglé la course de la porte, constaté interrupteur d'isolement mal * réglé, réglé e.o. * - Remis le joint inférieur car sortie de son logement * e.o. * UHR_LOPEZ"}]
# [{'date_time': '09.05.2024 03:06:07', 'comment': '* Ausfallart (Störungsursache): * übrige Störungen * * Behebungsmassnahme 1 (Störungsursache): * Test / Simulation durchgeführt * * System BHM 2 (Störungsursache): * Führungselement * *'}, {'date_time': '09.05.2024 03:06:07', 'comment': '* Mass: Beide Linearführungen ersetzt. * Rechtes Türblatt Exzenter schräg montiert. Exzenter korrekt montiert und * Türblatt eingestellt. * Fanghacken rechts zu lang, ersetzt durch kürzeren Typ. * Fanghacken links abgenutzt und krumm, ersetzt. * Höhe Drehsäule rechts eingestellt. * Einklemmschutzgummi unten gerichtet, Blech war schräg. * IBS erfolgreich. Funktionskontrolle Gesamtsystem nicht ausgeführt, * andere Tür am Zug offen ausgeschaltet. * Türverschiebekraft knapp unter 150N. Türe pendelt bis zu 2x nach Reset.'}]
# [{'date_time': '30.04.2024 09:28:24', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Führungselement * --> ... * * Lokalisierung (Störungsursache): * Türe 3 * * Symptom (Störungsbild): * abgebrochen * * System BHM 1 (Störungsursache): * Führungselement * *'}, {'date_time': '30.04.2024 09:28:25', 'comment': '* Gewinde defekt und viel Sekunden Leim *'}, {'date_time': '30.04.2024 09:29:49', 'comment': '* Gewinde abgebrochen und viel Reste des Sekundenleims *'}, {'date_time': '30.04.2024 16:40:37', 'comment': '* Ausfallart (Störungsursache): * übrige Störungen * * Behebungsmassnahme 1 (Störungsursache): * Test / Simulation durchgeführt * * System BHM 2 (Störungsursache): * Führungselement * *'}, {'date_time': '30.04.2024 16:40:37', 'comment': '* Mass: Obere Linearführung ersetzt. * Türblatt eingestellt. * Fanghacken links ersetzt duurch kleineren Typ. * IBS erfolgreich.'}]
# [{'date_time': '20.04.2024 20:34:33', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> ... * * Lokalisierung (Störungsursache): * Türe 3 * * Symptom (Störungsbild): * gestört - ZEITWEISE * *'}, {'date_time': '20.04.2024 20:34:34', 'comment': '* Lf fand Türe abgetrennt vor. *'}]
# [{'date_time': '17.04.2024 15:33:59', 'comment': "* Genre de panne (Cause): * n'engage pas / n'atteint pas la position finale * * : * Unité d’arrêt avec carré de verrouillage * * Mesure de réparation 1 (Cause): * remplacé * * : * Unité d’arrêt avec carré de verrouillage * *"}, {'date_time': '17.04.2024 15:33:59', 'comment': '* Remplacement du carré s effectué. * En ordre.'}]
# [{'date_time': '15.04.2024 15:07:36', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türsteuerung lokal --> Türrechner * * Lokalisierung (Störungsursache): * Türe 2 * * Symptom (Störungsbild): * blockiert * * Ausfallart (Störungsursache): * Wackelkontakt / kalte Lötstelle * * System BHM 1 (Störungsursache): * Türrechner * * Behebungsmassnahme 1 (Störungsursache): * abgedichtet * * System BHM 2 (Störungsursache): * Türrechner * *'}, {'date_time': '15.04.2024 15:07:38', 'comment': '* Die Lichtschranke hat ein Wackelkontakt, wodurch die ET nur mit * Zwangsverriegelung schlisst. *'}, {'date_time': '15.04.2024 15:39:21', 'comment': '* korrektur: Die Lichtschranke verliert zum teil kontakt. ebenfalls * leuchtet die Rote Meldelampe, sobald die Türe geschlossen ist. * Abtrennschalter ist nicht blockiert. Im Hardi sind keine Abweichungen * oder Fehler zu sehen. * ET abgetrennt. * Verdacht auf defekten Türrechner. *'}, {'date_time': '19.04.2024 13:57:18', 'comment': '* IOW KÜM: Türrechner agw, neu geladen. Bei Funktionskontrolle ist immer * noch das gleiche Störungsbild vorhanden. genauere Diagnose * im UH nötig. ET bleibt abgetrennt. *'}, {'date_time': '13.05.2024 03:24:32', 'comment': '* Verkabelungen kontrolliert und festgestellt, Kabel mit der Beschriftung * 16/15 siehe Bild war in der Klemmleiste falsch * angeschlossen auf 17/16. Richtig angeschlossen und geprüft. i.O'}]
# ...
# [{'date_time': '26.08.2022 02:53:41', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (Störungsursache): * 2 * * Symptom (Störungsbild): * Test/Prüfung nicht erfolgreich * * Ausfallart (Störungsursache): * mechanische Leistungswerte ausserhalb Toleranz * * System BHM 1 (Störungsursache): * Ver-/ Entriegelungseinheit * *'}, {'date_time': '26.08.2022 02:53:42', 'comment': '* Drehfalle hat keinen Siegellack muss ersetzt werden. *'}, {'date_time': '06.10.2022 15:38:24', 'comment': '* Avis passé en WENT * MOUGIN *'}, {'date_time': '10.11.2022 09:47:46', 'comment': "* Ces S1 concernant la colonne pivotante ne peuvent toujours pas être * traitées. Nous n'avons pas encore reçu toutes les informations *  nécessaires de la part de Bode. * Les numéros d'article des outils sont actuellement en cours d'ouverture * et nous avons revu le document de Bode, mais il n'est pas * encore validé. * MOUGIN *"}, {'date_time': '10.03.2023 13:20:40', 'comment': '* Butée réglée selon Instruction Michel Müller et remis la porte en * service par la dérogation AAZ12578936 * Introduit mesure "résiduel à l\'entretien 200000kms". *'}, {'date_time': '18.01.2024 09:14:04', 'comment': '* Mesure de réparation 1 (Cause): * vérifié selon la liste de contrôle * * : * Unité de verrouillage/déverrouillage * *'}, {'date_time': '18.01.2024 09:14:05', 'comment': '* "Grâce à la CAA 12591260, le repositionnement temporaire de la butée * selon la validation spéciale AAZ 12578936 a été transformé en *  une mesure corrective correcte. La notification est close".'}]
# [{'date_time': '26.08.2022 02:59:07', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (Störungsursache): * 2 * * Symptom (Störungsbild): * Test/Prüfung nicht erfolgreich * * Ausfallart (Störungsursache): * mechanische Leistungswerte ausserhalb Toleranz * * System BHM 1 (Störungsursache): * Ver-/ Entriegelungseinheit * *'}, {'date_time': '26.08.2022 02:59:08', 'comment': '* Drehfalle hat keinen Siegellack muss ersetzt werden. *'}, {'date_time': '06.10.2022 15:45:26', 'comment': '* Avis passé en WENT * MOUGIN *'}, {'date_time': '10.11.2022 09:51:32', 'comment': "* Ces S1 concernant la colonne pivotante ne peuvent toujours pas être * traitées. Nous n'avons pas encore reçu toutes les informations *  nécessaires de la part de Bode. * Les numéros d'article des outils sont actuellement en cours d'ouverture * et nous avons revu le document de Bode, mais il n'est pas * encore validé. * MOUGIN *"}, {'date_time': '10.03.2023 13:30:12', 'comment': '* Butée réglée selon Instruction Michel Müller et remis la porte en * service par la dérogation AAZ12578936 * Introduit mesure "résiduel à l\'entretien 200000kms". *'}, {'date_time': '18.01.2024 09:17:59', 'comment': '* Mesure de réparation 1 (Cause): * vérifié selon la liste de contrôle * * : * Unité de verrouillage/déverrouillage * *'}, {'date_time': '18.01.2024 09:17:59', 'comment': '* "Grâce à la CAA 12591260, le repositionnement temporaire de la butée * selon la validation spéciale AAZ 12578936 a été transformé en *  une mesure corrective correcte. La notification est close".'}]
# [{'date_time': '26.08.2022 02:59:43', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (Störungsursache): * 3 * * Symptom (Störungsbild): * Test/Prüfung nicht erfolgreich * * Ausfallart (Störungsursache): * mechanische Leistungswerte ausserhalb Toleranz * * System BHM 1 (Störungsursache): * Ver-/ Entriegelungseinheit * *'}, {'date_time': '26.08.2022 02:59:44', 'comment': '* Drehfalle hat keinen Siegellack muss ersetzt werden. *'}, {'date_time': '06.10.2022 15:44:51', 'comment': '* Avis passé en WENT * MOUGIN *'}, {'date_time': '10.11.2022 09:50:48', 'comment': "* Ces S1 concernant la colonne pivotante ne peuvent toujours pas être * traitées. Nous n'avons pas encore reçu toutes les informations *  nécessaires de la part de Bode. * Les numéros d'article des outils sont actuellement en cours d'ouverture * et nous avons revu le document de Bode, mais il n'est pas * encore validé. * MOUGIN *"}, {'date_time': '10.03.2023 13:28:37', 'comment': '* Butée réglée selon Instruction Michel Müller et remis la porte en * service par la dérogation AAZ12578936 * Introduit mesure "résiduel à l\'entretien 200000kms". *'}, {'date_time': '18.01.2024 09:17:11', 'comment': '* Mesure de réparation 1 (Cause): * vérifié selon la liste de contrôle * * : * Unité de verrouillage/déverrouillage * *'}, {'date_time': '18.01.2024 09:17:11', 'comment': '* "Grâce à la CAA 12591260, le repositionnement temporaire de la butée * selon la validation spéciale AAZ 12578936 a été transformé en *  une mesure corrective correcte. La notification est close".'}]
# [{'date_time': '26.08.2022 02:56:59', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (Störungsursache): * 4 * * Symptom (Störungsbild): * Test/Prüfung nicht erfolgreich * * Ausfallart (Störungsursache): * mechanische Leistungswerte ausserhalb Toleranz * * System BHM 1 (Störungsursache): * Ver-/ Entriegelungseinheit * *'}, {'date_time': '26.08.2022 02:57:00', 'comment': '* Drehfalle hat keinen Siegellack muss ersetzt werden. *'}, {'date_time': '06.10.2022 15:43:06', 'comment': '* Avis passé en WENT * MOUGIN *'}, {'date_time': '10.11.2022 09:49:16', 'comment': "* Ces S1 concernant la colonne pivotante ne peuvent toujours pas être * traitées. Nous n'avons pas encore reçu toutes les informations *  nécessaires de la part de Bode. * Les numéros d'article des outils sont actuellement en cours d'ouverture * et nous avons revu le document de Bode, mais il n'est pas * encore validé. * MOUGIN *"}, {'date_time': '10.03.2023 13:26:03', 'comment': '* Butée réglée selon Instruction Michel Müller et remis la porte en * service par la dérogation AAZ12578936 * Introduit mesure "résiduel à l\'entretien 200000kms". *'}, {'date_time': '18.01.2024 09:15:26', 'comment': '* Mesure de réparation 1 (Cause): * vérifié selon la liste de contrôle * * : * Unité de verrouillage/déverrouillage * *'}, {'date_time': '18.01.2024 09:15:44', 'comment': '* "Grâce à la CAA 12591260, le repositionnement temporaire de la butée * selon la validation spéciale AAZ 12578936 a été transformé en *  une mesure corrective correcte. La notification est close".'}]
# [{'date_time': '26.07.2022 03:30:01', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (Störungsursache): * 3 * * Symptom (Störungsbild): * lose * * Ausfallart (Störungsursache): * lose * * System BHM 1 (Störungsursache): * Ver-/ Entriegelungseinheit * *'}, {'date_time': '26.07.2022 03:30:02', 'comment': '* Schraube bei Endschalter der Primärdrehfalle ist lose. * Primärdrehfalle bestellt, bitte tauschen. *'}, {'date_time': '09.05.2023 10:40:09', 'comment': '* Diag: Kein Mat. in Res.Zone gefunden. * Mass: Primärdrehfalle ersetzt. IBS erfolgreich. *'}, {'date_time': '09.05.2023 10:40:47', 'comment': '* Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Ver-/ Entriegelungseinheit *'}]
# [{'date_time': '04.07.2022 10:10:33', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türnotöffnung --> * v-Schwellen-Schaltung Notentriegelung * * Lokalisierung (Störungsursache): * 3 * * Symptom (Störungsbild): * schwergängig * * Ausfallart (Störungsursache): * blockiert / verklemmt / schwergängig * * System BHM 1 (Störungsursache): * v-Schwellen-Schaltung Notentriegelung * *'}, {'date_time': '04.07.2022 10:10:34', 'comment': '* Türe33 Notentriegelung aussen klemmt. Muss ersetzt werden. *'}, {'date_time': '05.10.2022 23:48:09', 'comment': '* Behebungsmassnahme 1 (Störungsursache): * Test / Simulation durchgeführt * * System BHM 2 (Störungsursache): * v-Schwellen-Schaltung Notentriegelung * *'}, {'date_time': '05.10.2022 23:48:09', 'comment': '* IOW KÜM: Notentrigelung Außen 220 N innen 180N beide sind zu hoch. * jeduch sind die Notlösezüge nicht wirklich schwergängig oder * haken. Verrigelung vom Motor ist unter 21 Nm. Drehfalle muss getauscht * werden. *'}, {'date_time': '28.02.2023 09:59:00', 'comment': '* Diag: Es wurde eine Doppelmeldung auf der selben Türe eröffnet   128943229. Es wurde bereits der äussere Bowdenzug ersetzt. * Die zweite Meldung wurde nun geschlossen. * Erw.Mass: Gemäss Eintrag vom 05.10: Drehfalle tauschen. * EAA 20320376 Prüfung1, 2 und die nötigen Punkte für die getauschte   Drehfalle *'}, {'date_time': '14.03.2023 16:20:47', 'comment': '* Mass: Drehfalle ersetzt. Äusserer Bowdenzug in Toleranz. * Innerer Bowdenzug bleibt beim Rückstellen hängen. Umlenkwippe verbogen, * ersetzt. * IBS ausgeführt. Abstecken der Winkelgetriebeeinheit und Umlenkrolle * nicht möglich. * Rep. aus Zeitmangel abgebrochen. * Erw.Mass: Winkelgetriebeeinheit und Umlenkrolle positionieren. * Zahnriemen einstellen. *'}, {'date_time': '21.04.2023 11:04:58', 'comment': '* Behebungsmassnahme 1 (Störungsursache): * eingestellt / justiert * * Behebungsmassnahme 2 (Störungsursache): * ersetzt * * System BHM 3 (Störungsursache): * v-Schwellen-Schaltung Notentriegelung * * Behebungsmassnahme 3 (Störungsursache): * geprüft gem. Checkliste * *'}, {'date_time': '21.04.2023 11:04:58', 'comment': '* Winkelgetriebeeinheit, Motorendanschlag und Umlenkrolle korrekt * positioniert, Schrauben und Spannscheiben ersetzt, mit korrektem * Drehmoment angezogen und markiert. * ZR Spannung eingestellt auf 43.3Hz, Frequenzdifferenz liegt bei 7Hz. und * ist I.O. * Übertotpunktlage mit Lampe und Spiegel kontrolliert, I.O. * Zeit für Wissensaustausch auch auf diese Meldung verbucht. *'}, {'date_time': '21.04.2023 14:49:59', 'comment': '* Bei Zugsausfahrt wurde festgestellt, dass die Grünschlaufe unterbrochen * ist und eine Fahrsperre vorliegt. * Diese Tür abgetrennt, Grünschlaufe nun I.O. * Im Gf Primärdrehfalle ausgemessen, diese hatte tw. einen Unterbruch. * Primärdrehfalle im Gf getauscht, mit Drehmoment festgezogen und * markiert. * Simulation durchgeführt und Übertotpunktlage erneut kontrolliert, I.O.'}]
# [{'date_time': '21.06.2022 08:03:57', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türsteuerung & -bedienung * Zugebene --> ... * * Lokalisierung (Störungsursache): * 2 * * Symptom (Störungsbild): * pendelt * *'}, {'date_time': '21.06.2022 08:03:58', 'comment': '* Türe 02 Pendelte und liess sich nur noch mit Türreset jeweils schliessen * -> Abgetrennt *'}, {'date_time': '01.07.2022 23:19:20', 'comment': '* Türe bleibt blockiert nach wenigen cm. Kommt sie über den Punkt bleibt * sie ca 30cm vor Schliessung Blockiert. Gereinigt geschmiert *  ohne Erfolg. Untere Linearführung tauschen. Mat bestellt. *'}, {'date_time': '05.08.2022 13:56:26', 'comment': '* Diag: Anzugsmoment M6 Schraube Seite Türblatt abgeklärt. * Schraube soll nach 11618639 Seite 51 Allgemeine Anzugsmomente angezogen * werden (Schraubentyp konnte nicht abgeklärt werden). * Erw.Mass: Linearführung unten ersetzen. *'}, {'date_time': '07.11.2022 21:06:56', 'comment': '* Ergänzung aus Meldung 127555874: * Zahnriemenspannung der Türe ist zu gering muss eingestellt werden beim * Tausch der Linearführung *'}, {'date_time': '08.02.2023 14:04:17', 'comment': '* Ausfallart (Störungsursache): * blockiert / verklemmt / schwergängig * * System BHM 1 (Störungsursache): * Türsteuerung & -bedienung Zugebene * * Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Türsteuerung & -bedienung Zugebene * * Behebungsmassnahme 2 (Störungsursache): * eingestellt / justiert * * System BHM 3 (Störungsursache): * Türsteuerung & -bedienung Zugebene * * Behebungsmassnahme 3 (Störungsursache): * Test / Simulation durchgeführt * *'}, {'date_time': '08.02.2023 14:04:17', 'comment': '* Untere Linearführung massiv verklemmt, diese getauscht, beide * Linearführungen richtig geschmiert und gereinigt. * Zahnriemenspannung war bei 34Hz. Diese eingestellt auf 44.2Hz. * IBS Protokoll nach AAZ 11618639 für Tausch Linearführungen durchgeführt. * Dabei festgestellt, dass das X-Mass oben bei 73mm liegt, * die Türblattparallelität beidseitig nicht stimmt und die Drehsäulenhöhe * zu klein ist (Ist 4mm, Soll 7-10mm) Sämtliche * Einstellungen auf Sollwert eingestellt, sämtliche Schrauben und * Spannscheiben getauscht, mit Drehmoment angezogen und markiert. * Übertotpunktlage mit Lampe und Spiegel kontrolliert, diese ist I.O.'}]
# [{'date_time': '21.06.2022 08:03:57', 'comment': '* System (Störungsursache): * Einstiegssysteme --> Einstiegstüre --> Türsteuerung & -bedienung * Zugebene --> ... * * Lokalisierung (Störungsursache): * 2 * * Symptom (Störungsbild): * pendelt * *'}, {'date_time': '21.06.2022 08:03:58', 'comment': '* Türe 02 Pendelte und liess sich nur noch mit Türreset jeweils schliessen * -> Abgetrennt *'}, {'date_time': '01.07.2022 23:19:20', 'comment': '* Türe bleibt blockiert nach wenigen cm. Kommt sie über den Punkt bleibt * sie ca 30cm vor Schliessung Blockiert. Gereinigt geschmiert *  ohne Erfolg. Untere Linearführung tauschen. Mat bestellt. *'}, {'date_time': '05.08.2022 13:56:26', 'comment': '* Diag: Anzugsmoment M6 Schraube Seite Türblatt abgeklärt. * Schraube soll nach 11618639 Seite 51 Allgemeine Anzugsmomente angezogen * werden (Schraubentyp konnte nicht abgeklärt werden). * Erw.Mass: Linearführung unten ersetzen. *'}, {'date_time': '07.11.2022 21:06:56', 'comment': '* Ergänzung aus Meldung 127555874: * Zahnriemenspannung der Türe ist zu gering muss eingestellt werden beim * Tausch der Linearführung *'}, {'date_time': '08.02.2023 14:04:17', 'comment': '* Ausfallart (Störungsursache): * blockiert / verklemmt / schwergängig * * System BHM 1 (Störungsursache): * Türsteuerung & -bedienung Zugebene * * Behebungsmassnahme 1 (Störungsursache): * ersetzt * * System BHM 2 (Störungsursache): * Türsteuerung & -bedienung Zugebene * * Behebungsmassnahme 2 (Störungsursache): * eingestellt / justiert * * System BHM 3 (Störungsursache): * Türsteuerung & -bedienung Zugebene * * Behebungsmassnahme 3 (Störungsursache): * Test / Simulation durchgeführt * *'}, {'date_time': '08.02.2023 14:04:17', 'comment': '* Untere Linearführung massiv verklemmt, diese getauscht, beide * Linearführungen richtig geschmiert und gereinigt. * Zahnriemenspannung war bei 34Hz. Diese eingestellt auf 44.2Hz. * IBS Protokoll nach AAZ 11618639 für Tausch Linearführungen durchgeführt. * Dabei festgestellt, dass das X-Mass oben bei 73mm liegt, * die Türblattparallelität beidseitig nicht stimmt und die Drehsäulenhöhe * zu klein ist (Ist 4mm, Soll 7-10mm) Sämtliche * Einstellungen auf Sollwert eingestellt, sämtliche Schrauben und * Spannscheiben getauscht, mit Drehmoment angezogen und markiert. * Übertotpunktlage mit Lampe und Spiegel kontrolliert, diese ist I.O.'}]
# [{'date_time': '06.01.2023 09:26:15', 'comment': '* Tür muss ersetzt werden (MT5/3 Einstiegs Richtung LINKS) nach Absprache * mit PDT Thomas Bührer. Bitte neu planen. *'}, {'date_time': '06.01.2023 09:27:21', 'comment': '* Behebungsmassnahme 2 (Störungsursache): * geprüft gem. Checkliste * * System BHM 3 (Störungsursache): * Türblatt / Türflügel komplett * *'}, {'date_time': '23.02.2023 15:35:22', 'comment': '* Betroffenes Türblatt ist in der Reservierten Zone. Bitte bei Gelegenheit   tauschen *'}, {'date_time': '13.04.2023 07:54:17', 'comment': '* Status 19 gesetzt aufgrund Langläufer-Meldung (Bald 500 Tage offen) * Bitte Türflügel ersetzen. *'}, {'date_time': '02.05.2023 16:01:30', 'comment': '* Mass: Türflügel ersetzt und eingestellt. * Abdichtgummi oben musste gerichtet werden. * Führungsschiene Fanghacken gängig gemacht. * IBS erfolgreich. Türe schlägt leicht beim öffnen, in Toleranz.'}]

# %%
# Extract the door number from the maintenance log and put it as a column
def extract_door_number(text):
    pattern = r'(?:Localisation \(Cause\)|Lokalisierung \(Störungsursache\)):\s*\*?\s*(?:Türe|Porte)?\s*(\d+)\s*\*?'
    match = re.search(pattern, text, re.IGNORECASE)
    if match:
        return match.group(1)
    else:
        return None

df["door"] = df["maintenance_log"].apply(extract_door_number)
df.dropna(subset=['door'], inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df['maintenance_log'] = df['log_number'].map(lambda log_number: [f"issue_{int(log_number)}_log_{i+1}" for i in range(len(extract_logs(df.loc[df['log_number'] == log_number, 'maintenance_log'].values[0])))])
print(df)

print(json.dumps(log_dict, indent=4))
# Out:
#     train_number                                 problem  log_number  \
# 0          015-5                Primärdrehfalle tauschen   131479425
# 1          001-5  -ET-Antriebsmotor 1 gestört-zeitwei...   131471966
# 2          047-8                -ET-Rechner 3 Stör.Aktiv   131461040
# 3          023-9           -ET-Rechner 2 schliesst nicht   131351602
# 4          113-8                     +ÜT moteur 5 bloqué   131332603
# ..           ...                                     ...         ...
# 153        120-3           ET verrouillage 4 AAZ12578936   128404198
# 154        024-7                  ET-Verriegelung 3 lose   128275990
# 155        046-0     ET-v-Schwelle Notent 3 schwergängig   128189630
# 156        056-9             -Türsteuerung Zug 2 pendelt   128140205
# 157        056-9             -Türsteuerung Zug 2 pendelt   128140205
#
#                                        maintenance_log fault_start_date  \
# 0    [issue_131479425_log_1, issue_131479425_log_2,...       2024-09-18
# 1    [issue_131471966_log_1, issue_131471966_log_2,...       2024-09-17
# 2    [issue_131461040_log_1, issue_131461040_log_2,...       2024-09-14
# 3    [issue_131351602_log_1, issue_131351602_log_2,...       2024-08-18
# 4    [issue_131332603_log_1, issue_131332603_log_2,...       2024-08-14
# ..                                                 ...              ...
# 153  [issue_128404198_log_1, issue_128404198_log_2,...       2022-08-26
# 154  [issue_128275990_log_1, issue_128275990_log_2,...       2022-07-26
# 155  [issue_128189630_log_1, issue_128189630_log_2,...       2022-07-04
# 156  [issue_128140205_log_1, issue_128140205_log_2,...       2022-06-21
# 157  [issue_128140205_log_1, issue_128140205_log_2,...       2022-06-21
#
#                                 material_name  \
# 0      Drehfalle vollständig zu Einstiegstüre
# 1           Türsteuerung BODE 25-004-1019-301
# 2      Drehfalle vollständig zu Einstiegstüre
# 3                   Handschalter zu Türflügel
# 4    Türsteuerung MTS-L 1.14 zu Uebergangstür
# ..                                        ...
# 153    Drehfalle vollständig zu Einstiegstüre
# 154    Drehfalle vollständig zu Einstiegstüre
# 155    Drehfalle vollständig zu Einstiegstüre
# 156         Reinigungsset für SBB-Instrumente
# 157   Flachkopf-TORX-Schraube M6x8 mit Tuflok
#
#                                      maintenance_steps  \
# 0            Sonstige → Test / Simulation durchgeführt
# 1                         HW/Elektr. & Mech. → ersetzt
# 2    HW/Elektr. & Mech. → ersetzt ; HW/Elektr. & Me...
# 3                         HW/Elektr. & Mech. → ersetzt
# 4                         HW/Elektr. & Mech. → ersetzt
# ..                                                 ...
# 153                 Sonstige → geprüft gem. Checkliste
# 154                       HW/Elektr. & Mech. → ersetzt
# 155  HW/Elektr. & Mech. → eingestellt / justiert ; ...
# 156  HW/Elektr. & Mech. → ersetzt ; HW/Elektr. & Me...
# 157  HW/Elektr. & Mech. → ersetzt ; HW/Elektr. & Me...
#
#                                       cause_of_failure        BODE code door
# 0               Software & Firmware → übrige Störungen  25-341-0119-101    3
# 1    HW/Elektr. & Mech. - elektrisch → spricht nich...  25-004-1019-301    1
# 2    HW/Elektr. & Mech. - elektrisch → Fehler Daten...  25-341-0119-101    3
# 3    HW/Elektr. & Mech. - elektrisch → spricht unbe...  25-310-0566-202    2
# 4               Software & Firmware → übrige Störungen  25-004-1019-301    5
# ..                                                 ...              ...  ...
# 153  HW/Elektr. & Mech. - mechanisch → mechanische ...  25-341-0119-101    4
# 154  HW/Elektr. & Mech. - mechanisch → lose / unzur...  25-341-0119-101    3
# 155  HW/Elektr. & Mech. - mechanisch → blockiert / ...  25-341-0119-101    3
# 156  HW/Elektr. & Mech. - mechanisch → blockiert / ...  25-004-1019-301    2
# 157  HW/Elektr. & Mech. - mechanisch → blockiert / ...  25-004-1019-301    2
#
# [158 rows x 10 columns]
# {
#     "issue_131479425_log_1": {
#         "date_time": "18.09.2024 12:56:19",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 3 * * Symptom (St\u00f6rungsbild): * lose * *"
#     },
#     "issue_131479425_log_2": {
#         "date_time": "18.09.2024 12:55:02",
#         "comment": "*"
#     },
#     "issue_131479425_log_3": {
#         "date_time": "18.09.2024 12:54:54",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 1 * * Symptom (St\u00f6rungsbild): * lose * *"
#     },
#     "issue_131479425_log_4": {
#         "date_time": "18.09.2024 12:54:39",
#         "comment": "* Beim Kontrollauftrag/\u00c4nderungsauftrag Bolzenmarkierung wurde an der MT23   eine Drehfalle mit gebrochenem Siegellack an der Mutter des Bolzens   gefunden. Die Mutter des Bolzens war lose. * Mutter wurde wieder angezogen. * Die Prim\u00e4rdrehfalle 94-000-1950A muss beim n\u00e4chsten UH ersetzt werden *"
#     },
#     "issue_131479425_log_5": {
#         "date_time": "20.09.2024 16:11:04",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * \u00fcbrige St\u00f6rungen * * System BHM 1 (St\u00f6rungsursache): * Ver-/ Entriegelungseinheit * * Behebungsmassnahme 1 (St\u00f6rungsursache): * Test / Simulation durchgef\u00fchrt * * System BHM 2 (St\u00f6rungsursache): * Ver-/ Entriegelungseinheit * *"
#     },
#     "issue_131479425_log_6": {
#         "date_time": "20.09.2024 16:11:04",
#         "comment": "* Diag: Drehfallen an Lager waren nicht markiert. * Mass: Drehfalle gem\u00e4ss Dok: 20390489 markiert. * Drehfalle ersetzt. IBS erfolgreich."
#     },
#     "issue_131471966_log_1": {
#         "date_time": "17.09.2024 09:18:21",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 1 * * Symptom (St\u00f6rungsbild): * gest\u00f6rt - ZEITWEISE * *"
#     },
#     "issue_131471966_log_2": {
#         "date_time": "17.09.2024 09:18:22",
#         "comment": "* ET1: \u00f6ffnet nicht - abgetrennt *"
#     },
#     "issue_131471966_log_3": {
#         "date_time": "28.09.2024 03:19:14",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * spricht nicht an * * System BHM 1 (St\u00f6rungsursache): * Einstiegst\u00fcre * * Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * * System BHM 2 (St\u00f6rungsursache): * Einstiegst\u00fcre * *"
#     },
#     "issue_131471966_log_4": {
#         "date_time": "28.09.2024 03:23:07",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrantrieb elektr. --> Motor zu * T\u00fcrantrieb *"
#     },
#     "issue_131461040_log_1": {
#         "date_time": "14.09.2024 06:23:11",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrsteuerung lokal --> T\u00fcrrechner * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 3 * * Symptom (St\u00f6rungsbild): * St\u00f6rungsanzeige aktiv * * Sofortmassnahme: * Abgetrennt/abgesperrt * *"
#     },
#     "issue_131461040_log_2": {
#         "date_time": "14.09.2024 06:23:12",
#         "comment": "* Abgetrennt vorgefunden *"
#     },
#     "issue_131461040_log_3": {
#         "date_time": "19.09.2024 02:34:03",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * Fehler Datenkommunikation * * System BHM 1 (St\u00f6rungsursache): * T\u00fcrrechner * * Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * * System BHM 2 (St\u00f6rungsursache): * T\u00fcrrechner * * Behebungsmassnahme 2 (St\u00f6rungsursache): * eingestellt / justiert * * System BHM 3 (St\u00f6rungsursache): * T\u00fcrrechner * * Behebungsmassnahme 3 (St\u00f6rungsursache): * gepr\u00fcft gem. Checkliste * *"
#     },
#     "issue_131461040_log_4": {
#         "date_time": "19.09.2024 02:34:06",
#         "comment": "* Mit UH PC Fehlerspeicher kontrolliert. Fehler Verriegelungsschalter div. * Male aufgetreten. * Prim\u00e4rdrehfalle getauscht und Verriegelungsstange eingestellt, da kein * Spiel vorhanden war. * IBS nach Vorgabe durchgef\u00fchrt und Protokoll sowie Pr\u00fcfnummer Drehmoment * angeh\u00e4ngt"
#     },
#     "issue_131460609_log_1": {
#         "date_time": "13.09.2024 21:30:31",
#         "comment": "* System (St\u00f6rungsursache): * Innenausbau & Inneneinrichtung --> Innent\u00fcren --> Innent\u00fcre Fahrgastraum * / Abteilt\u00fcre / Trennung 1./2. Klasse --> T\u00fcrantrieb elektr. * * Lokalisierung (St\u00f6rungsursache): * Wagenende/Fahrzeugende 2 innen * * Symptom (St\u00f6rungsbild): * abgenutzt * *"
#     },
#     "issue_131460609_log_2": {
#         "date_time": "13.09.2024 21:30:32",
#         "comment": "* Streift beim \u00f6ffnen bzw. schliessen. *"
#     },
#     "issue_131460609_log_3": {
#         "date_time": "16.09.2024 14:27:12",
#         "comment": "* System (St\u00f6rungsursache): * Kupplung & Fahrzeug\u00fcbergang --> Wagen\u00fcbergangst\u00fcre / Brandschutzschott * --> T\u00fcrsteuerung \u00dcbergangst\u00fcre --> T\u00fcrrechner * * Lokalisierung (St\u00f6rungsursache): * Wagenende/Fahrzeugende 1 innen * * Ausfallart (St\u00f6rungsursache): * \u00fcbrige St\u00f6rungen * * System BHM 1 (St\u00f6rungsursache): * T\u00fcrrechner * *"
#     },
#     "issue_131460609_log_4": {
#         "date_time": "16.09.2024 14:27:12",
#         "comment": "* T\u00fcrf\u00fchrung gereinigt, T\u00fcre Streift nicht mehr. * Fehlermeldung E3A= Inkremente defekt (sehe Bild). * Verkabelung vom Motor angesehen, nichts auff\u00e4lliges feststellen k\u00f6nnen. * T\u00fcrrehner ausgekreuzt ,Fehler ist gewandert. * T\u00fcrrechner nicht auf Lager. * E-Mail an MVS gemacht. * Materialnummer: 94-001-3454A * N\u00e4chste UH Rechner tauschen. *"
#     },
#     "issue_131460609_log_5": {
#         "date_time": "27.09.2024 14:08:50",
#         "comment": "* Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * * System BHM 2 (St\u00f6rungsursache): * T\u00fcrrechner * * Behebungsmassnahme 2 (St\u00f6rungsursache): * Update / Upgrade aufgespielt * * System BHM 3 (St\u00f6rungsursache): * T\u00fcrrechner * * Behebungsmassnahme 3 (St\u00f6rungsursache): * gepr\u00fcft gem. Checkliste * *"
#     },
#     "issue_131460609_log_6": {
#         "date_time": "27.09.2024 14:08:50",
#         "comment": "* T\u00fcrrechner getauscht, SW aktualisiert, Referenzfahrt/Messfahrt * durchgef\u00fchrt und Baudrate auf 9600 angepasst. * Simulation durchgef\u00fchrt, T\u00fcr l\u00e4uft wieder einwandfrei und gleichm\u00e4ssig * mit anderer \u00dcT."
#     },
#     "issue_131351602_log_1": {
#         "date_time": "18.08.2024 13:41:57",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrsteuerung lokal --> T\u00fcrrechner * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 2 * * Symptom (St\u00f6rungsbild): * schliesst nicht * * Sofortmassnahme: * Abgetrennt und gegen Wiederinbetriebnahme gesichert * *"
#     },
#     "issue_131351602_log_2": {
#         "date_time": "18.08.2024 13:41:58",
#         "comment": "* T\u00fcre wurde abgetrennt vorgerfunden *"
#     },
#     "issue_131351602_log_3": {
#         "date_time": "28.08.2024 10:56:23",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * spricht unbegr\u00fcndet an * * System BHM 1 (St\u00f6rungsursache): * T\u00fcrrechner * * Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * * System BHM 2 (St\u00f6rungsursache): * T\u00fcrrechner * *"
#     },
#     "issue_131351602_log_4": {
#         "date_time": "28.08.2024 10:56:23",
#         "comment": "* T\u00fcre kontrolliert und festgestellt das der S-Schalter innen in Stellung * \u00f6ffnen Blockiert war. * An der der T\u00fcr 1 auch das selbe. An der T\u00fcre 1 und 2 S-Schalter innen * ersetzt. i.O"
#     },
#     "issue_131332603_log_1": {
#         "date_time": "14.08.2024 22:07:53",
#         "comment": "* Syst\u00e8me (Cause): * Attelage et plaque d\u2019intercirculation --> Porte de plaque * d\u2019intercirculation/cloison coupe-feu --> Entra\u00eenement \u00e9lectrique de * porte * * Localisation (Cause): * 5 * * D\u00e9tail localisation: * MT5 * * Sympt\u00f4me (Image): * bloqu\u00e9 * *"
#     },
#     "issue_131332603_log_2": {
#         "date_time": "14.08.2024 22:07:54",
#         "comment": "* LS75D: * Diagnostic: * - Constat\u00e9 porte intercirculation MT5 ne s'ouvre pas, constat\u00e9 d\u00e9faut * incr\u00e9mentation, apr\u00e8s reset et course de r\u00e9f\u00e9rence, en ordre *  la porte fonctionne. * - Constat\u00e9 un ant\u00e9c\u00e9dent le 20.06.2024, moteur a \u00e9t\u00e9 remplac\u00e9 pour la * m\u00eame cause de d\u00e9rangement. * R\u00e9paration n\u00e9cessaire: * - \u00e0 contr\u00f4le durant 5 jours si le d\u00e9faut revient. *"
#     },
#     "issue_131332603_log_3": {
#         "date_time": "23.08.2024 13:04:54",
#         "comment": "* Genre de panne (Cause): * autres perturbations * * : * Moteur de l\u2019entra\u00eenement de porte * *"
#     },
#     "issue_131332603_log_4": {
#         "date_time": "23.08.2024 13:04:54",
#         "comment": "* - Repris le diag sur la MT5 * - Plusieurs d\u00e9rangement en historique --> moteur d\u00e9j\u00e0 remplac\u00e9 * - Remplac\u00e9 le calculateur, charg\u00e9 soft 1.05 * - R\u00e9gl\u00e9 la course de la porte * - Contr\u00f4l\u00e9 fonctionnement de la porte intercirculation --> OK * - Laiss\u00e9 avis en P23, sous 15j * UHR_LOPEZ *"
#     },
#     "issue_131332603_log_5": {
#         "date_time": "01.09.2024 15:26:33",
#         "comment": "* Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * *System BHM 2 (St\u00f6rungsursache): * Motor zu T\u00fcrantrieb * *"
#     },
#     "issue_131332603_log_6": {
#         "date_time": "01.09.2024 15:26:34",
#         "comment": "* Controll\u00e9 il y a plus d'erreurs e.o. *"
#     },
#     "issue_131332603_log_7": {
#         "date_time": "01.09.2024 15:45:52",
#         "comment": "* En traversant a la fin * La porte etais de noubeau en panne *"
#     },
#     "issue_131332603_log_8": {
#         "date_time": "08.09.2024 15:26:51",
#         "comment": "* Trouver porte d\u00e9fectueux * Contr\u00f4ler avec UHPC et porte remis en service * Je pense que c'est le calculateur qui est d\u00e9fectueux * A voir au prochain passage si le d\u00e9faut reviens * Sinon faudra changer le calculateur avec une autre porte voir si le * d\u00e9faut se d\u00e9place * A suivre... *"
#     },
#     "issue_131332603_log_9": {
#         "date_time": "12.09.2024 16:02:21",
#         "comment": "* GE75D: * Constat\u00e9 porte MT5 hors service de nouveau aujourd'hui * Effectu\u00e9 reset sans succ\u00e8s * R\u00e9paration necessaire: * Contr\u00f4ler calculateur *"
#     },
#     "issue_131332603_log_10": {
#         "date_time": "17.09.2024 01:49:26",
#         "comment": "* GE75D: * Effectu\u00e9 reset du calculateur de la porte + plusieurs essais, * fonctionnement en ordre ce jour * Remarque: * A suivre *"
#     },
#     "issue_131332603_log_11": {
#         "date_time": "17.09.2024 08:41:43",
#         "comment": "* GE75D * Diagnostic : * - Porte \u00e0 nouveau en d\u00e9rangement. La porte n'ouvre pas. * R\u00e9paration effectu\u00e9e : * - Fait reset du calculateur sans succ\u00e8s ; la porte s'ouvre \u00e0 moiti\u00e9 puis * ne s'ouvre plus. * - Fait un reset de la porte en position ouverte et essais ; en ordre * pour le moment. * R\u00e9paration n\u00e9cessaire : * - Calculateur \u00e0 contr\u00f4ler. *"
#     },
#     "issue_131332603_log_12": {
#         "date_time": "21.09.2024 15:50:06",
#         "comment": "* - sur la porte MT5 MW4 --> le calculateur et moteur ont d\u00e9j\u00e0 \u00e9t\u00e9 * remplac\u00e9 * - Contr\u00f4l\u00e9 le c\u00e2ble dans la gaine anaconda --> R.A.S ( l'alimentation * des boutons) * - Pour avanc\u00e9 le diag --> voulu permut\u00e9 le calculateur entre MT5 et MT6 * --> NOK, lorsque les 2 calculateurs ont \u00e9t\u00e9 permut\u00e9, * aucune portes fonctionnaient. * - Remis le calculateur sur la MT6 * - Remplac\u00e9 le calculateur de la MT5 et charg\u00e9 soft 1.05 * - Remplac\u00e9 aussi le moteur de la MT5 * - R\u00e9gl\u00e9 la course de la porte e.o. * - Je laisse l'avis ouvert sous 15j * En attente * UHR_LOPEZ *"
#     },
#     "issue_131332603_log_13": {
#         "date_time": "27.09.2024 12:17:43",
#         "comment": "* - Constat\u00e9 en arrivant sur la rame, porte MT5 MW4 en d\u00e9rangement \" * incr\u00e9mentation H.S\" * - Charg\u00e9 \u00e0 nouveau le soft en s\u00e9lectionnant porte MT5 sur l'UHPC * - Contr\u00f4l\u00e9 les fonctions de la porte avec le programme --> R.A.S * - Contr\u00f4l\u00e9 le c\u00e2blage du calculateur au moteur --> constat\u00e9 connecteur * X4 mal fix\u00e9 * - Connect\u00e9 correctement * - Essay\u00e9 de bouger les c\u00e2bles lors de l'ouverture / fermeture -> R.A.S * - Laiss\u00e9 l'avis ouvert pendant 15j, a suivre * UHR_LOPEZ *"
#     },
#     "issue_131332603_log_14": {
#         "date_time": "28.09.2024 12:47:08",
#         "comment": "* contr\u00f4ler ce jours pas constater de d\u00e9rangements porte fonctionnelle  a * suivre sous 14j *"
#     },
#     "issue_131332603_log_15": {
#         "date_time": "30.09.2024 08:06:01",
#         "comment": "* Pas de nouveau d\u00e9faut * avis ferm\u00e9 * UHR GUILLAUME"
#     },
#     "issue_131304580_log_1": {
#         "date_time": "08.08.2024 00:35:41",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 1 * * Symptom (St\u00f6rungsbild): * gest\u00f6rt - ZEITWEISE * * Ausfallart (St\u00f6rungsursache): * fehlt * * System BHM 1 (St\u00f6rungsursache): * Einstiegst\u00fcre * *"
#     },
#     "issue_131304580_log_2": {
#         "date_time": "08.08.2024 00:35:42",
#         "comment": "* Bei T002 festgestellt: T\u00fcr 1 abgetrennt. DDS Nr. 17025 *"
#     },
#     "issue_131304580_log_3": {
#         "date_time": "08.08.2024 03:21:48",
#         "comment": "* Behebungsmassnahme 1 (St\u00f6rungsursache): * Test / Simulation durchgef\u00fchrt * * System BHM 2 (St\u00f6rungsursache): * Einstiegst\u00fcre * *"
#     },
#     "issue_131304580_log_4": {
#         "date_time": "08.08.2024 03:21:51",
#         "comment": "* UH-PC angeh\u00e4ngt zum Fehlerspeicher auszulesen. * Fehlermeldung : Maximale Anzahl Schliessungs Versuche \u00fcberschritten, * dauerhaft anstehend. * Im Fehlerspeicher ist diese Meldung nicht zu sehen Fehler kann auch * nicht quittiert werden. * T\u00fcre Mechanisch Gepr\u00fcft --> Bei der Prim\u00e4rdrehfalle ist der * Verriegelungs-Kontrollschalter verklemmt dieser ist dauerbet\u00e4tigt. * Der Endschalter konnte wieder g\u00e4ngig  gemacht werden jedoch verklemmt * dieser immer wieder. * T\u00fcre wieder sicher verriegelt (\u00dcbertotlage ist gegeben) und abgetrennt. * Dazugeh\u00f6rige Massnahme erstellt. * ------------------------ * Im n\u00e4chstem UH bitte Prim\u00e4rdrehfalle tauschen. Artikelnummer * 94-000-1950A / Lagerort 02-01-B/R *"
#     },
#     "issue_131304580_log_5": {
#         "date_time": "25.08.2024 13:30:59",
#         "comment": "* Prim\u00e4rdrehfalle wurde ersetzt. IBS-Protokoll durchgef\u00fchrt i.o"
#     },
#     "issue_131280057_log_1": {
#         "date_time": "01.08.2024 07:39:06",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 1 * * Symptom (St\u00f6rungsbild): * \u00f6ffnet nicht * *"
#     },
#     "issue_131280057_log_2": {
#         "date_time": "01.08.2024 07:39:07",
#         "comment": "* - Einstiegst\u00fcre MT41 \u00f6ffnet nicht \u00fcber \u00d6ffnungstaster innen wie aussen * - Bhf LS * - Einstiegst\u00fcre verriegelt und gekennzeichnet *"
#     },
#     "issue_131280057_log_3": {
#         "date_time": "01.08.2024 13:37:12",
#         "comment": "* LS75D * - Constat\u00e9 multitude de d\u00e9faut sur cette porte , suite a simulation avec * le PC , constat\u00e9 que le marche pied ne sort pas . * Effectu\u00e9 un reset de la porte et plusieurs essais en ordre . * - Quand j'ai voulu faire les essais depuis la cabine , la porte c'est * remise en d\u00e9faut - senseur marche pied . * - Porte verrouill\u00e9e et cart\u00e9e * R\u00e9paration n\u00e9cessaire : * - A contr\u00f4ler lors d'un arr\u00eat prolong\u00e9 . *"
#     },
#     "issue_131280057_log_4": {
#         "date_time": "19.08.2024 12:40:32",
#         "comment": "* Genre de panne (Cause): * ne r\u00e9pond pas * * : * Porte d\u2019acc\u00e8s * *"
#     },
#     "issue_131280057_log_5": {
#         "date_time": "19.08.2024 12:40:35",
#         "comment": "* - Normalis\u00e9 porte 41, pas d\u00e9faut apparent * - Connect\u00e9 l'UHPC, constat\u00e9 des d\u00e9fauts sporadiques qui durent 1 sec * - \"d\u00e9faut relai K2, d\u00e9faut de tension\" * - Remplac\u00e9 le calculateur, contr\u00f4l\u00e9 soft 1.14 * - Contr\u00f4l\u00e9 fonctionnement de la porte --> e.o. * - Plus d'erreur sporadique, e.o.* Porte remis en service * UHR_LOPEZ *"
#     },
#     "issue_131280057_log_6": {
#         "date_time": "19.08.2024 12:40:59",
#         "comment": "* Mesure de r\u00e9paration 1 (Cause): * remplac\u00e9 * * : * Porte d\u2019acc\u00e8s *"
#     },
#     "issue_131252085_log_1": {
#         "date_time": "25.07.2024 08:46:52",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 2 * * Symptom (St\u00f6rungsbild): * schliesst nicht * * Sofortmassnahme: * Abgetrennt/abgesperrt * *"
#     },
#     "issue_131252085_log_2": {
#         "date_time": "25.07.2024 08:46:53",
#         "comment": "* T\u00fcr schliesst nicht. Abgetrennt *"
#     },
#     "issue_131252085_log_3": {
#         "date_time": "12.08.2024 16:01:04",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * abgebrochen / zerbrochen / abgerissen * * System BHM 1 (St\u00f6rungsursache): * Einstiegst\u00fcre * * Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * * System BHM 2 (St\u00f6rungsursache): * Einstiegst\u00fcre * * Behebungsmassnahme 2 (St\u00f6rungsursache): * gepr\u00fcft gem. Checkliste * * System BHM 3 (St\u00f6rungsursache): * Einstiegst\u00fcre * *"
#     },
#     "issue_131252085_log_4": {
#         "date_time": "12.08.2024 16:01:07",
#         "comment": "* Beim Anschliessen des UH PCs bzw. \u00d6ffnen der Deckenklappe ist ein Teil * des Verriegelungskontrollschalters runtergefallen. * Prim\u00e4rdrehfalle getauscht und IBS nach Vorgabe durchgef\u00fchrt"
#     },
#     "issue_131243142_log_1": {
#         "date_time": "23.07.2024 06:08:19",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Schiebetritt --> Schiebetrittantrieb elektr. * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 2 * * Symptom (St\u00f6rungsbild): * f\u00e4hrt nicht ein * * Sofortmassnahme: * Abgetrennt/abgesperrt * *"
#     },
#     "issue_131243142_log_2": {
#         "date_time": "23.07.2024 06:08:20",
#         "comment": "* T\u00fcre 02 abgetrennt Schiebetritt f\u00e4hrt nicht ein *"
#     },
#     "issue_131243142_log_3": {
#         "date_time": "31.07.2024 03:13:17",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * startet nicht / l\u00e4sst sich nicht einschalten * * System BHM 1 (St\u00f6rungsursache): * Schiebetrittantrieb elektr. * * Behebungsmassnahme 1 (St\u00f6rungsursache): * Messwert(e) ausgelesen / erfasst * * System BHM 2 (St\u00f6rungsursache): * Schiebetrittantrieb elektr. * * Behebungsmassnahme 2 (St\u00f6rungsursache): * ersetzt * * System BHM 3 (St\u00f6rungsursache): * Schiebetrittantrieb elektr. * * Behebungsmassnahme 3 (St\u00f6rungsursache): * gepr\u00fcft gem. Checkliste * *"
#     },
#     "issue_131243142_log_4": {
#         "date_time": "31.07.2024 03:13:19",
#         "comment": "* Zuerst Schiebetritt kontrolliert. Mit UH PC und in ausgeschaltetem * Zustand keine Abweichungen festgestellt. Schiebetritt l\u00e4uft * sehr leichtg\u00e4ngig. * T\u00fcre zeigt Fehler Verriegelungsschalter. Nur 1x anstehend gewesen. Neue * Drehfalle elektrisch angeschlossen und Simulation * durchgef\u00fchrt, T\u00fcr l\u00e4uft normal. * Prim\u00e4rdrehfalle getauscht und IBS nach Vorgabe durchgef\u00fchrt. Protokoll * und Pr\u00fcfnummer Drehmomentschl\u00fcssel angeh\u00e4ngt"
#     },
#     "issue_131234440_log_1": {
#         "date_time": "20.07.2024 15:41:38",
#         "comment": "* System (St\u00f6rungsursache): * Kupplung & Fahrzeug\u00fcbergang --> Wagen\u00fcbergangst\u00fcre / Brandschutzschott * --> ... * * Lokalisierung (St\u00f6rungsursache): * Zwischendeck WE1 * * Symptom (St\u00f6rungsbild): * \u00f6ffnet nicht * *"
#     },
#     "issue_131234440_log_2": {
#         "date_time": "20.07.2024 15:41:39",
#         "comment": "* Repair&Clean Mailer * +++++++++++++++++++++++ * Wagen\u00fcbergangst\u00fcre; \u00d6ffnet nicht automatisch * * Erstintervention * - Welche \u00dcbergangst\u00fcre ist betroffen? * > Zwischendeck Seite 1 (MT5) * - Ist die Brandschutzfunktion der \u00dcbergangst\u00fcre noch vorhanden? * > Ja, \u00dcbergangst\u00fcre schliesst vollst\u00e4ndig, muss einfach von Hand * ge\u00f6ffnet werden und schliesst danach wieder korrekt. * - Ist die benachbarte \u00dcbergangst\u00fcre in Betrieb? * > Ja, \u00dcbergangst\u00fcre normal in Betrieb. * * Zus\u00e4tzliche Beschreibung * nur noch manueller betrieb m\u00f6glich * *"
#     },
#     "issue_131234440_log_3": {
#         "date_time": "12.08.2024 02:19:06",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * \u00fcbrige St\u00f6rungen * * System BHM 1 (St\u00f6rungsursache): * Wagen\u00fcbergangst\u00fcre / Brandschutzschott * *"
#     },
#     "issue_131234440_log_4": {
#         "date_time": "12.08.2024 02:19:06",
#         "comment": "* Inkrementalgeber defekt, laut T\u00fcrrechner. Motor getauscht, Fehler * bleibt. Aufgefallen, dass die Litzen des Inkrementalgebers * vertauscht angeschlossen sind. Litzen nach Beschriftung angeschlossen, * Fehler bleibt. Motor wieder r\u00fcckgetauscht. T\u00fcrverschalung * demontiert um alle Stecker und Litzen zu \u00fcberpr\u00fcfen, i.O. * T\u00fcrrechner getauscht, SW geladen. * Fehler weg, aber Inkrementalgeber z\u00e4hlt r\u00fcckw\u00e4rts. Festgestellt, dass im * Schema gr\u00fcn und gelb das Inkrementalgebers vertauscht * sind, dass heisst, die Litzen sind verkehrt beschriftet. Schema f\u00fcr * Abteilt\u00fcr geholt und gesehen, dass da gr\u00fcn und gelb nach * Beschriftung stimmen. * Da eine Seite der Abteilt\u00fcr den gleichen Motor hat, wie die * \u00dcbergangst\u00fcr, ist das etwas verwirrend. * Litzen nach Schema angeschlossen, Mess/Referenzfahrt ausgef\u00fchrt, i.O. *"
#     },
#     "issue_131234440_log_5": {
#         "date_time": "12.08.2024 02:20:32",
#         "comment": "* Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * * System BHM 2 (St\u00f6rungsursache): * Wagen\u00fcbergangst\u00fcre / Brandschutzschott * *"
#     },
#     "issue_131234440_log_6": {
#         "date_time": "12.08.2024 02:20:32",
#         "comment": "* Ini zum Abtrennen der T\u00fcr gerichtet und eingestellt."
#     },
#     "issue_131198042_log_1": {
#         "date_time": "11.07.2024 14:35:12",
#         "comment": "* Syst\u00e8me (Cause): * Syst\u00e8mes d\u2019acc\u00e8s --> Porte d\u2019acc\u00e8s --> Commande des portes, locale --> * Calculateur de porte * * Localisation (Cause): * Porte 4 * * Sympt\u00f4me (Image): * d\u00e9clench\u00e9 * * Genre de panne (Cause): * d\u00e9marre pas / ne se laisse pas enclencher * * : * Calculateur de porte * *"
#     },
#     "issue_131198042_log_2": {
#         "date_time": "11.07.2024 15:44:16",
#         "comment": "* Trouv\u00e9 porte cart\u00e9 * Constat\u00e9 error qui viens sporadiquement. Quand la porte se ouvre et se * ferme. On a l'impression que c'est le calculateur. * On l'a chang\u00e9. * Maitenant l'error ne reviens plus, * Par contre pas reu\u00e7i de charger la soft. A faire au prochaine paasage *"
#     },
#     "issue_131198042_log_3": {
#         "date_time": "16.07.2024 09:53:31",
#         "comment": "* Mesure de r\u00e9paration 1 (Cause): * mise \u00e0 jour effectu\u00e9e * * : * Calculateur de porte * *"
#     },
#     "issue_131198042_log_4": {
#         "date_time": "16.07.2024 09:53:32",
#         "comment": "* Soft charge ce jour * E.O apr\u00e8s chargement * UHR GUILLAUME"
#     },
#     "issue_131166013_log_1": {
#         "date_time": "03.07.2024 14:43:02",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> F\u00fchrungselement * --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 3 * * Symptom (St\u00f6rungsbild): * lose * *"
#     },
#     "issue_131166013_log_2": {
#         "date_time": "03.07.2024 14:41:46",
#         "comment": "* An dieser Einstiegst\u00fcr m\u00fcssen alle Befestigungsschrauben der F\u00fchrungsschiene beider Linearf\u00fchrungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben \u201eFlachkopf-TORX-Schraube M6x8 mit Tuflok\" 94-003-1630 m\u00fcssen einzeln getauscht werden und gem\u00e4ss BBA 20398308, mit 9.5 Nm angezogen werden und sind entweder im T\u00fcrgitterschrank oder unter dem Lagerplatz 0600 P\u00fcnten Magazin AK-34-19-1 zu finden. *"
#     },
#     "issue_131166013_log_3": {
#         "date_time": "03.07.2024 09:30:33",
#         "comment": "* Symptom (St\u00f6rungsbild): * lose *"
#     },
#     "issue_131166013_log_4": {
#         "date_time": "14.08.2024 14:42:48",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * abgebrochen / zerbrochen / abgerissen * * System BHM 1 (St\u00f6rungsursache): * F\u00fchrungselement * *"
#     },
#     "issue_131166013_log_5": {
#         "date_time": "14.08.2024 14:42:50",
#         "comment": "* Schrauben einzeln getauscht der unteren Linearf\u00fchrung. Bei der oberen * Linearf\u00fchrung sind 2 Schrauben abgerissen ohne den * geringsten Kraftaufwand. Linearf\u00fchrung ausgebaut und versucht, die * Schrauben aus der Gleitschiene auszubauen. Mit kleiner Flex 2 * Schlitze gefr\u00e4st und mit Heissluftf\u00f6hn und Schlitzschraubendreher * versucht, Schrauben auszubauen, ohne Erfolg. * Mit Bohrer und Linksdrall konnten die Schrauben entfernt werden. * Linearf\u00fchrung getauscht und IBS nach Vorgabe durchgef\u00fchrt. * Linkes T\u00fcrblatt eingestellt, da Parallelit\u00e4t nicht stimmte sowie die * Fanghaken des linken T\u00fcr. 5 Schrauben des T\u00fcrblattes ersetzt, * mit 27Nm angezogen und markiert. * IBS Protokoll,Schliesskraftmessprotokoll sowie Pr\u00fcfnummern der * Drehmomentschl\u00fcssel der Meldung angeh\u00e4ngt. *"
#     },
#     "issue_131166013_log_6": {
#         "date_time": "14.08.2024 14:43:58",
#         "comment": "* Behebungsmassnahme 1 (St\u00f6rungsursache): * Fremdk\u00f6rper entfernt * * System BHM 2 (St\u00f6rungsursache): * F\u00fchrungselement * * Behebungsmassnahme 2 (St\u00f6rungsursache): * ersetzt * * System BHM 3 (St\u00f6rungsursache): * F\u00fchrungselement * * Behebungsmassnahme 3 (St\u00f6rungsursache): * eingestellt / justiert *"
#     },
#     "issue_131166571_log_1": {
#         "date_time": "03.07.2024 18:04:48",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 2 * * Symptom (St\u00f6rungsbild): * schliesst nicht * * Sofortmassnahme: * Abgetrennt und gegen Wiederinbetriebnahme gesichert * *"
#     },
#     "issue_131166571_log_2": {
#         "date_time": "03.07.2024 18:04:51",
#         "comment": "* T\u00fcr durch LF abgetrennt (schliesst nicht). *"
#     },
#     "issue_131166571_log_3": {
#         "date_time": "11.07.2024 15:17:10",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * abgebrochen / zerbrochen / abgerissen * * System BHM 1 (St\u00f6rungsursache): * Einstiegst\u00fcre * * Behebungsmassnahme 1 (St\u00f6rungsursache): * Messwert(e) ausgelesen / erfasst * * System BHM 2 (St\u00f6rungsursache): * Einstiegst\u00fcre * * Behebungsmassnahme 2 (St\u00f6rungsursache): * ersetzt * * System BHM 3 (St\u00f6rungsursache): * Einstiegst\u00fcre * * Behebungsmassnahme 3 (St\u00f6rungsursache): * gepr\u00fcft gem. Checkliste * *"
#     },
#     "issue_131166571_log_4": {
#         "date_time": "11.07.2024 15:17:13",
#         "comment": "* Mit UH PC Messwerte, Fehlerspeicher und Motorstromkurven kontrolliert. * Auff\u00e4llig ist, das 54x Schiebetrittbelastung aufgetreten * ist. Schiebetritt l\u00e4uft normal und keine Ger\u00e4uschbildung h\u00f6rbar. * T\u00fcrsystem freigegeben und Simulation durchgef\u00fchrt. T\u00fcr \u00f6ffnet normal * aber in geschlossenem Zustand versucht die T\u00fcr weiterhin noch * mehr zu schliessen und geht dann in St\u00f6rung.* T\u00fcrsystem ausgeschaltet und Prim\u00e4rdrehfalle kontrolliert. Bet\u00e4tigungsarm * des Schnappschalters der Drehfalle gebrochen, daher * Drehfalle komplett getauscht und IBS nach Vorgabe durchgef\u00fchrt. * IBS Protokoll, Schliesskraftprotokoll und Drehmomentpr\u00fcfnummer der * Meldung angeh\u00e4ngt. * T\u00fcr l\u00e4uft wieder einwandfrei und die \u00dcbertotpunktlage ist I.O."
#     },
#     "issue_131164287_log_1": {
#         "date_time": "03.07.2024 09:36:27",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> F\u00fchrungselement * --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 1 * * Symptom (St\u00f6rungsbild): * lose * *"
#     },
#     "issue_131164287_log_2": {
#         "date_time": "03.07.2024 09:34:49",
#         "comment": "* An dieser Einstiegst\u00fcr m\u00fcssen alle Befestigungsschrauben der F\u00fchrungsschiene beider Linearf\u00fchrungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben \u201eFlachkopf-TORX-Schraube M6x8 mit Tuflok\" 94-003-1630 m\u00fcssen einzeln getauscht werden und gem\u00e4ss BBA 20398308, mit 9.5 Nm angezogen werden und sind entweder im T\u00fcrgitterschrank oder unter dem Lagerplatz 0600 P\u00fcnten Magazin AK-34-19-1 zu finden. *"
#     },
#     "issue_131164287_log_3": {
#         "date_time": "03.07.2024 09:30:33",
#         "comment": "* Symptom (St\u00f6rungsbild): * lose *"
#     },
#     "issue_131164310_log_1": {
#         "date_time": "03.07.2024 09:40:58",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> F\u00fchrungselement * --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 3 * * Symptom (St\u00f6rungsbild): * lose * *"
#     },
#     "issue_131164310_log_2": {
#         "date_time": "03.07.2024 09:39:17",
#         "comment": "* An dieser Einstiegst\u00fcr m\u00fcssen alle Befestigungsschrauben der   F\u00fchrungsschiene beider Linearf\u00fchrungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben \u201eFlachkopf-TORX-Schraube M6x8 mit Tuflok\" 94-003-1630   m\u00fcssen einzeln getauscht werden und gem\u00e4ss BBA 20398308, mit 9.5 Nm   angezogen werden und sind entweder im T\u00fcrgitterschrank oder unter dem   Lagerplatz 0600 P\u00fcnten Magazin AK-34-19-1 zu finden. *"
#     },
#     "issue_131164310_log_3": {
#         "date_time": "03.07.2024 09:30:33",
#         "comment": "* Symptom (St\u00f6rungsbild): * lose *"
#     },
#     "issue_131164310_log_4": {
#         "date_time": "12.07.2024 10:15:50",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * falsches Bauteil eingebaut * * System BHM 1 (St\u00f6rungsursache): * F\u00fchrungselement * * Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * * System BHM 2 (St\u00f6rungsursache): * F\u00fchrungselement * * Behebungsmassnahme 2 (St\u00f6rungsursache): * festgezogen * * System BHM 3 (St\u00f6rungsursache): * F\u00fchrungselement * *"
#     },
#     "issue_131164310_log_5": {
#         "date_time": "12.07.2024 10:15:53",
#         "comment": "* Alle Schrauben einzeln getauscht und mit 9.5Nm angezogen. Pr\u00fcfnummer * Drehmomentschl\u00fcssel im Anhang"
#     },
#     "issue_131164331_log_1": {
#         "date_time": "03.07.2024 09:46:53",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> F\u00fchrungselement * --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 1 * * Symptom (St\u00f6rungsbild): * lose * *"
#     },
#     "issue_131164331_log_2": {
#         "date_time": "03.07.2024 09:45:38",
#         "comment": "* An dieser Einstiegst\u00fcr m\u00fcssen alle Befestigungsschrauben der   F\u00fchrungsschiene beider Linearf\u00fchrungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben \u201eFlachkopf-TORX-Schraube M6x8 mit Tuflok\" 94-003-1630   m\u00fcssen einzeln getauscht werden und gem\u00e4ss BBA 20398308, mit 9.5 Nm   angezogen werden und sind entweder im T\u00fcrgitterschrank oder unter dem   Lagerplatz 0600 P\u00fcnten Magazin AK-34-19-1 zu finden. *"
#     },
#     "issue_131164331_log_3": {
#         "date_time": "03.07.2024 09:30:33",
#         "comment": "* Symptom (St\u00f6rungsbild): * lose *"
#     },
#     "issue_131164331_log_4": {
#         "date_time": "09.07.2024 10:44:04",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * falsches Bauteil eingebaut * * System BHM 1 (St\u00f6rungsursache): * F\u00fchrungselement * * Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * * System BHM 2 (St\u00f6rungsursache): * F\u00fchrungselement * * Behebungsmassnahme 2 (St\u00f6rungsursache): * festgezogen * * System BHM 3 (St\u00f6rungsursache): * F\u00fchrungselement * *"
#     },
#     "issue_131164331_log_5": {
#         "date_time": "09.07.2024 10:44:07",
#         "comment": "* Alle 30 Schrauben einzeln ersetzt und mit 9.5Nm angezogen"
#     },
#     "issue_131166012_log_1": {
#         "date_time": "03.07.2024 14:41:32",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> F\u00fchrungselement * --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 1 * * Symptom (St\u00f6rungsbild): * lose * *"
#     },
#     "issue_131166012_log_2": {
#         "date_time": "03.07.2024 14:40:21",
#         "comment": "* An dieser Einstiegst\u00fcr m\u00fcssen alle Befestigungsschrauben der   F\u00fchrungsschiene beider Linearf\u00fchrungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben \u201eFlachkopf-TORX-Schraube M6x8 mit Tuflok\" 94-003-1630   m\u00fcssen einzeln getauscht werden und gem\u00e4ss BBA 20398308, mit 9.5 Nm   angezogen werden und sind entweder im T\u00fcrgitterschrank oder unter dem   Lagerplatz 0600 P\u00fcnten Magazin AK-34-19-1 zu finden. *"
#     },
#     "issue_131166012_log_3": {
#         "date_time": "03.07.2024 09:30:33",
#         "comment": "* Symptom (St\u00f6rungsbild): * lose *"
#     },
#     "issue_131165990_log_1": {
#         "date_time": "03.07.2024 14:38:27",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> F\u00fchrungselement * --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 1 * * Symptom (St\u00f6rungsbild): * lose * *"
#     },
#     "issue_131165990_log_2": {
#         "date_time": "03.07.2024 14:36:41",
#         "comment": "* An dieser Einstiegst\u00fcr m\u00fcssen alle Befestigungsschrauben der   F\u00fchrungsschiene beider Linearf\u00fchrungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben \u201eFlachkopf-TORX-Schraube M6x8 mit Tuflok\" 94-003-1630   m\u00fcssen einzeln getauscht werden und gem\u00e4ss BBA 20398308, mit 9.5 Nm   angezogen werden und sind entweder im T\u00fcrgitterschrank oder unter dem   Lagerplatz 0600 P\u00fcnten Magazin AK-34-19-1 zu finden. *"
#     },
#     "issue_131165990_log_3": {
#         "date_time": "03.07.2024 09:30:33",
#         "comment": "* Symptom (St\u00f6rungsbild): * lose *"
#     },
#     "issue_131159150_log_1": {
#         "date_time": "02.07.2024 08:39:34",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> F\u00fchrungselement * --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 3 * *"
#     },
#     "issue_131159150_log_2": {
#         "date_time": "02.07.2024 08:38:12",
#         "comment": "* An dieser Einstiegst\u00fcr m\u00fcssen alle Befestigungsschrauben der   F\u00fchrungsschiene beider Linearf\u00fchrungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben \u201eFlachkopf-TORX-Schraube M6x8 mit Tuflok\" 94-003-1630   m\u00fcssen einzeln getauscht werden und gem\u00e4ss BBA 20398308, mit 9.5 Nm   angezogen werden und sind entweder im T\u00fcrgitterschrank oder unter dem   Lagerplatz 0600 P\u00fcnten Magazin AK-34-19-1 zu finden. *"
#     },
#     "issue_131159150_log_3": {
#         "date_time": "03.07.2024 09:30:51",
#         "comment": "* Symptom (St\u00f6rungsbild): * lose * *"
#     },
#     "issue_131159133_log_1": {
#         "date_time": "02.07.2024 08:34:01",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> F\u00fchrungselement * --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 2 * *"
#     },
#     "issue_131159133_log_2": {
#         "date_time": "02.07.2024 08:31:10",
#         "comment": "* An dieser Einstiegst\u00fcr m\u00fcssen alle Befestigungsschrauben der   F\u00fchrungsschiene beider Linearf\u00fchrungen (2x15 Stk.) einzeln ersetzt werd = en, weil die Gefahr besteht, dass Schrauben ohne Schraubensicherung verbaut wurden. * Die Schrauben \u201eFlachkopf-TORX-Schraube M6x8 mit Tuflok\" 94-003-1630   m\u00fcssen einzeln getauscht werden und gem\u00e4ss BBA 20398308, mit 9.5 Nm   angezogen werden und sind entweder im T\u00fcrgitterschrank oder unter dem   Lagerplatz 0600 P\u00fcnten Magazin AK-34-19-1 zu finden. *"
#     },
#     "issue_131159133_log_3": {
#         "date_time": "03.07.2024 09:32:00",
#         "comment": "* Symptom (St\u00f6rungsbild): * lose * *"
#     },
#     "issue_131159133_log_4": {
#         "date_time": "04.09.2024 12:45:11",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * verschlissen / abgenutzt * * System BHM 1 (St\u00f6rungsursache): * F\u00fchrungselement * * Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * * System BHM 2 (St\u00f6rungsursache): * F\u00fchrungselement * *"
#     },
#     "issue_131159133_log_5": {
#         "date_time": "04.09.2024 12:45:14",
#         "comment": "* Schrauben ersetzt * funktionskontrolle t\u00fcr i.o"
#     },
#     "issue_131124399_log_1": {
#         "date_time": "23.06.2024 22:26:05",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrblatt / T\u00fcrfl\u00fcgel komplett --> * ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 2 * * Symptom (St\u00f6rungsbild): * falsches Bauteil verbaut * * Ausfallart (St\u00f6rungsursache): * falsches Bauteil eingebaut * * System BHM 1 (St\u00f6rungsursache): * T\u00fcrblatt / T\u00fcrfl\u00fcgel komplett * *"
#     },
#     "issue_131124399_log_2": {
#         "date_time": "23.06.2024 22:26:06",
#         "comment": "* Festgestellt dass das falsche T\u00fcrblatt montiert ist, mit blauer * Rollstuhlfahrer Taste (siehe Bild). Abkl\u00e4rung mit PDT was dort * gemacht wird. *"
#     },
#     "issue_131124399_log_3": {
#         "date_time": "26.06.2024 13:23:47",
#         "comment": "* Bitte das falsche T\u00fcrblatt mit Rollstuhltaster auswechseln und das   korrekte T\u00fcrblatt 717-27-101A einbauen, Artikel wurde bestellt. * Bitte das ausgebaute T\u00fcrblatt begutachten ob es in einem guten Zustand   ist -> als A-Artikel 717-27-102A einlagern lassen, oder ob es   Besch\u00e4digungen hat und wir es als D-Material 717-27-102A zur\u00fcckschicken.   F\u00fcr die Entscheidung kann PDT dazugeholt werden. *"
#     },
#     "issue_131124399_log_4": {
#         "date_time": "15.07.2024 03:12:10",
#         "comment": "* Mass: T\u00fcrblatt ersetzt. * Neues T\u00fcrblatt kann nicht eingestellt werden. * T\u00fcrblatt im Bereich des Fanghackens nach innen verzogen. * Masse oder Verriegelungskraft ausser Toleranz, je nach Einstellung. * Nochmal T\u00fcrblatt bestellt. *Erw.Mass: T\u00fcrblatt erneut ersetzen. * 4x Befestigungsschrauben der linken Drehs\u00e4ule in den Wagenkasten * einstellen/ersetzen. *"
#     },
#     "issue_131124399_log_5": {
#         "date_time": "03.08.2024 07:36:34",
#         "comment": "* - T\u00fcre abgeschlossen und gekennzeichnet vorgefunden Grund unbekannt *"
#     },
#     "issue_131124399_log_6": {
#         "date_time": "03.08.2024 12:54:04",
#         "comment": "* ZUE75D: * T\u00fcre auf korrekten Verschluss gepr\u00fcft. * Gr\u00fcnschlaufe vorhanden. *"
#     },
#     "issue_131124399_log_7": {
#         "date_time": "30.09.2024 01:36:55",
#         "comment": "* Diag: Einlaufwinkel des anderen T\u00fcrblattes steht schon an w\u00e4hrend * schliessen. * Darum wirkte die andere T\u00fcr verzogen und die Verriegelungskraft war zu * hoch. * Mass: Einlaufwinkel eingestellt. * IBS erfolgreich. * Bestelltes T\u00fcrblatt im Magazin abgegeben. *"
#     },
#     "issue_131124399_log_8": {
#         "date_time": "30.09.2024 01:37:08",
#         "comment": "* Behebungsmassnahme 1 (St\u00f6rungsursache): * Reset / Neustart durchgef\u00fchrt * * System BHM 2 (St\u00f6rungsursache): * T\u00fcrblatt / T\u00fcrfl\u00fcgel komplett *"
#     },
#     "issue_131115647_log_1": {
#         "date_time": "21.06.2024 07:48:53",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> T\u00fcrsteuerung & -bedienung Zugebene --> ... * * Lokalisierung (St\u00f6rungsursache): * T\u00fcre 4 * * Symptom (St\u00f6rungsbild): * gest\u00f6rt - ZEITWEISE * *"
#     },
#     "issue_131115647_log_2": {
#         "date_time": "21.06.2024 07:48:54",
#         "comment": "* T\u00fcr schliesst nur mut Zwangsschliessung *"
#     },
#     "issue_131115647_log_3": {
#         "date_time": "02.07.2024 02:09:02",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * Fehler Datenkommunikation * * System BHM 1 (St\u00f6rungsursache): * T\u00fcrsteuerung & -bedienung Zugebene * * Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * * System BHM 2 (St\u00f6rungsursache): * T\u00fcrsteuerung & -bedienung Zugebene * *"
#     },
#     "issue_131115647_log_4": {
#         "date_time": "02.07.2024 02:09:02",
#         "comment": "* T\u00fcre kontrolliert und festgestellt das der Sender der Empf\u00e4nger der * Lichtschranke defekt ist. * Diesen ersetzt gepr\u00fcft io"
#     },
#     "issue_131108393_log_1": {
#         "date_time": "19.06.2024 11:42:03",
#         "comment": "* Syst\u00e8me (Cause): * Syst\u00e8mes d\u2019acc\u00e8s --> Porte d\u2019acc\u00e8s --> M\u00e9canisme de porte --> Unit\u00e9 de * verrouillage/d\u00e9verrouillage * * Localisation (Cause): * Porte 2 * * Sympt\u00f4me (Image): * bloqu\u00e9 * * Genre de panne (Cause): * mal connect\u00e9 * * : * Unit\u00e9 de verrouillage/d\u00e9verrouillage * *"
#     },
#     "issue_131108393_log_2": {
#         "date_time": "19.06.2024 11:42:05",
#         "comment": "* A l'arriv\u00e9e sur le train constat\u00e9 porte MT22 cart\u00e9 * Apr\u00e8s analyse constat\u00e9 capteur porte ferm\u00e9e HS (selon ordre BODE * interdit de remplacer capteur seul) * Verrouillage primaire a remplacer au prochain passage * UHR GUILLAUME ANDREETTI *"
#     },
#     "issue_131108393_log_3": {
#         "date_time": "26.06.2024 16:14:21",
#         "comment": "* J'ai chsnge le verouillage primaire. * Apr\u00e8s la porte etias tjr en panne. * A suivre *"
#     },
#     "issue_131108393_log_4": {
#         "date_time": "26.06.2024 16:22:57",
#         "comment": "* il affiche une dds dans la cabine un erreur de liberation. * pas p\u00fb poursuivre plus. * *"
#     },
#     "issue_131108393_log_5": {
#         "date_time": "26.07.2024 15:43:14",
# ...
#         "date_time": "18.01.2024 09:14:04",
#         "comment": "* Mesure de r\u00e9paration 1 (Cause): * v\u00e9rifi\u00e9 selon la liste de contr\u00f4le * * : * Unit\u00e9 de verrouillage/d\u00e9verrouillage * *"
#     },
#     "issue_128404196_log_7": {
#         "date_time": "18.01.2024 09:14:05",
#         "comment": "* \"Gr\u00e2ce \u00e0 la CAA 12591260, le repositionnement temporaire de la but\u00e9e * selon la validation sp\u00e9ciale AAZ 12578936 a \u00e9t\u00e9 transform\u00e9 en *  une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404201_log_1": {
#         "date_time": "26.08.2022 02:59:07",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (St\u00f6rungsursache): * 2 * * Symptom (St\u00f6rungsbild): * Test/Pr\u00fcfung nicht erfolgreich * * Ausfallart (St\u00f6rungsursache): * mechanische Leistungswerte ausserhalb Toleranz * * System BHM 1 (St\u00f6rungsursache): * Ver-/ Entriegelungseinheit * *"
#     },
#     "issue_128404201_log_2": {
#         "date_time": "26.08.2022 02:59:08",
#         "comment": "* Drehfalle hat keinen Siegellack muss ersetzt werden. *"
#     },
#     "issue_128404201_log_3": {
#         "date_time": "06.10.2022 15:45:26",
#         "comment": "* Avis pass\u00e9 en WENT * MOUGIN *"
#     },
#     "issue_128404201_log_4": {
#         "date_time": "10.11.2022 09:51:32",
#         "comment": "* Ces S1 concernant la colonne pivotante ne peuvent toujours pas \u00eatre * trait\u00e9es. Nous n'avons pas encore re\u00e7u toutes les informations *  n\u00e9cessaires de la part de Bode. * Les num\u00e9ros d'article des outils sont actuellement en cours d'ouverture * et nous avons revu le document de Bode, mais il n'est pas * encore valid\u00e9. * MOUGIN *"
#     },
#     "issue_128404201_log_5": {
#         "date_time": "10.03.2023 13:30:12",
#         "comment": "* But\u00e9e r\u00e9gl\u00e9e selon Instruction Michel M\u00fcller et remis la porte en * service par la d\u00e9rogation AAZ12578936 * Introduit mesure \"r\u00e9siduel \u00e0 l'entretien 200000kms\". *"
#     },
#     "issue_128404201_log_6": {
#         "date_time": "18.01.2024 09:17:59",
#         "comment": "* Mesure de r\u00e9paration 1 (Cause): * v\u00e9rifi\u00e9 selon la liste de contr\u00f4le * * : * Unit\u00e9 de verrouillage/d\u00e9verrouillage * *"
#     },
#     "issue_128404201_log_7": {
#         "date_time": "18.01.2024 09:17:59",
#         "comment": "* \"Gr\u00e2ce \u00e0 la CAA 12591260, le repositionnement temporaire de la but\u00e9e * selon la validation sp\u00e9ciale AAZ 12578936 a \u00e9t\u00e9 transform\u00e9 en *  une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404202_log_1": {
#         "date_time": "26.08.2022 02:59:43",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (St\u00f6rungsursache): * 3 * * Symptom (St\u00f6rungsbild): * Test/Pr\u00fcfung nicht erfolgreich * * Ausfallart (St\u00f6rungsursache): * mechanische Leistungswerte ausserhalb Toleranz * * System BHM 1 (St\u00f6rungsursache): * Ver-/ Entriegelungseinheit * *"
#     },
#     "issue_128404202_log_2": {
#         "date_time": "26.08.2022 02:59:44",
#         "comment": "* Drehfalle hat keinen Siegellack muss ersetzt werden. *"
#     },
#     "issue_128404202_log_3": {
#         "date_time": "06.10.2022 15:44:51",
#         "comment": "* Avis pass\u00e9 en WENT * MOUGIN *"
#     },
#     "issue_128404202_log_4": {
#         "date_time": "10.11.2022 09:50:48",
#         "comment": "* Ces S1 concernant la colonne pivotante ne peuvent toujours pas \u00eatre * trait\u00e9es. Nous n'avons pas encore re\u00e7u toutes les informations *  n\u00e9cessaires de la part de Bode. * Les num\u00e9ros d'article des outils sont actuellement en cours d'ouverture * et nous avons revu le document de Bode, mais il n'est pas * encore valid\u00e9. * MOUGIN *"
#     },
#     "issue_128404202_log_5": {
#         "date_time": "10.03.2023 13:28:37",
#         "comment": "* But\u00e9e r\u00e9gl\u00e9e selon Instruction Michel M\u00fcller et remis la porte en * service par la d\u00e9rogation AAZ12578936 * Introduit mesure \"r\u00e9siduel \u00e0 l'entretien 200000kms\". *"
#     },
#     "issue_128404202_log_6": {
#         "date_time": "18.01.2024 09:17:11",
#         "comment": "* Mesure de r\u00e9paration 1 (Cause): * v\u00e9rifi\u00e9 selon la liste de contr\u00f4le * * : * Unit\u00e9 de verrouillage/d\u00e9verrouillage * *"
#     },
#     "issue_128404202_log_7": {
#         "date_time": "18.01.2024 09:17:11",
#         "comment": "* \"Gr\u00e2ce \u00e0 la CAA 12591260, le repositionnement temporaire de la but\u00e9e * selon la validation sp\u00e9ciale AAZ 12578936 a \u00e9t\u00e9 transform\u00e9 en *  une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404198_log_1": {
#         "date_time": "26.08.2022 02:56:59",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (St\u00f6rungsursache): * 4 * * Symptom (St\u00f6rungsbild): * Test/Pr\u00fcfung nicht erfolgreich * * Ausfallart (St\u00f6rungsursache): * mechanische Leistungswerte ausserhalb Toleranz * * System BHM 1 (St\u00f6rungsursache): * Ver-/ Entriegelungseinheit * *"
#     },
#     "issue_128404198_log_2": {
#         "date_time": "26.08.2022 02:57:00",
#         "comment": "* Drehfalle hat keinen Siegellack muss ersetzt werden. *"
#     },
#     "issue_128404198_log_3": {
#         "date_time": "06.10.2022 15:43:06",
#         "comment": "* Avis pass\u00e9 en WENT * MOUGIN *"
#     },
#     "issue_128404198_log_4": {
#         "date_time": "10.11.2022 09:49:16",
#         "comment": "* Ces S1 concernant la colonne pivotante ne peuvent toujours pas \u00eatre * trait\u00e9es. Nous n'avons pas encore re\u00e7u toutes les informations *  n\u00e9cessaires de la part de Bode. * Les num\u00e9ros d'article des outils sont actuellement en cours d'ouverture * et nous avons revu le document de Bode, mais il n'est pas * encore valid\u00e9. * MOUGIN *"
#     },
#     "issue_128404198_log_5": {
#         "date_time": "10.03.2023 13:26:03",
#         "comment": "* But\u00e9e r\u00e9gl\u00e9e selon Instruction Michel M\u00fcller et remis la porte en * service par la d\u00e9rogation AAZ12578936 * Introduit mesure \"r\u00e9siduel \u00e0 l'entretien 200000kms\". *"
#     },
#     "issue_128404198_log_6": {
#         "date_time": "18.01.2024 09:15:26",
#         "comment": "* Mesure de r\u00e9paration 1 (Cause): * v\u00e9rifi\u00e9 selon la liste de contr\u00f4le * * : * Unit\u00e9 de verrouillage/d\u00e9verrouillage * *"
#     },
#     "issue_128404198_log_7": {
#         "date_time": "18.01.2024 09:15:44",
#         "comment": "* \"Gr\u00e2ce \u00e0 la CAA 12591260, le repositionnement temporaire de la but\u00e9e * selon la validation sp\u00e9ciale AAZ 12578936 a \u00e9t\u00e9 transform\u00e9 en *  une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128275990_log_1": {
#         "date_time": "26.07.2022 03:30:01",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrmechanik --> Ver-/ * Entriegelungseinheit * * Lokalisierung (St\u00f6rungsursache): * 3 * * Symptom (St\u00f6rungsbild): * lose * * Ausfallart (St\u00f6rungsursache): * lose * * System BHM 1 (St\u00f6rungsursache): * Ver-/ Entriegelungseinheit * *"
#     },
#     "issue_128275990_log_2": {
#         "date_time": "26.07.2022 03:30:02",
#         "comment": "* Schraube bei Endschalter der Prim\u00e4rdrehfalle ist lose. * Prim\u00e4rdrehfalle bestellt, bitte tauschen. *"
#     },
#     "issue_128275990_log_3": {
#         "date_time": "09.05.2023 10:40:09",
#         "comment": "* Diag: Kein Mat. in Res.Zone gefunden. * Mass: Prim\u00e4rdrehfalle ersetzt. IBS erfolgreich. *"
#     },
#     "issue_128275990_log_4": {
#         "date_time": "09.05.2023 10:40:47",
#         "comment": "* Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * * System BHM 2 (St\u00f6rungsursache): * Ver-/ Entriegelungseinheit *"
#     },
#     "issue_128189630_log_1": {
#         "date_time": "04.07.2022 10:10:33",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrnot\u00f6ffnung --> * v-Schwellen-Schaltung Notentriegelung * * Lokalisierung (St\u00f6rungsursache): * 3 * * Symptom (St\u00f6rungsbild): * schwerg\u00e4ngig * * Ausfallart (St\u00f6rungsursache): * blockiert / verklemmt / schwerg\u00e4ngig * * System BHM 1 (St\u00f6rungsursache): * v-Schwellen-Schaltung Notentriegelung * *"
#     },
#     "issue_128189630_log_2": {
#         "date_time": "04.07.2022 10:10:34",
#         "comment": "* T\u00fcre33 Notentriegelung aussen klemmt. Muss ersetzt werden. *"
#     },
#     "issue_128189630_log_3": {
#         "date_time": "05.10.2022 23:48:09",
#         "comment": "* Behebungsmassnahme 1 (St\u00f6rungsursache): * Test / Simulation durchgef\u00fchrt * * System BHM 2 (St\u00f6rungsursache): * v-Schwellen-Schaltung Notentriegelung * *"
#     },
#     "issue_128189630_log_4": {
#         "date_time": "05.10.2022 23:48:09",
#         "comment": "* IOW K\u00dcM: Notentrigelung Au\u00dfen 220 N innen 180N beide sind zu hoch. * jeduch sind die Notl\u00f6sez\u00fcge nicht wirklich schwerg\u00e4ngig oder * haken. Verrigelung vom Motor ist unter 21 Nm. Drehfalle muss getauscht * werden. *"
#     },
#     "issue_128189630_log_5": {
#         "date_time": "28.02.2023 09:59:00",
#         "comment": "* Diag: Es wurde eine Doppelmeldung auf der selben T\u00fcre er\u00f6ffnet   128943229. Es wurde bereits der \u00e4ussere Bowdenzug ersetzt. * Die zweite Meldung wurde nun geschlossen. * Erw.Mass: Gem\u00e4ss Eintrag vom 05.10: Drehfalle tauschen. * EAA 20320376 Pr\u00fcfung1, 2 und die n\u00f6tigen Punkte f\u00fcr die getauschte   Drehfalle *"
#     },
#     "issue_128189630_log_6": {
#         "date_time": "14.03.2023 16:20:47",
#         "comment": "* Mass: Drehfalle ersetzt. \u00c4usserer Bowdenzug in Toleranz. * Innerer Bowdenzug bleibt beim R\u00fcckstellen h\u00e4ngen. Umlenkwippe verbogen, * ersetzt. * IBS ausgef\u00fchrt. Abstecken der Winkelgetriebeeinheit und Umlenkrolle * nicht m\u00f6glich. * Rep. aus Zeitmangel abgebrochen. * Erw.Mass: Winkelgetriebeeinheit und Umlenkrolle positionieren. * Zahnriemen einstellen. *"
#     },
#     "issue_128189630_log_7": {
#         "date_time": "21.04.2023 11:04:58",
#         "comment": "* Behebungsmassnahme 1 (St\u00f6rungsursache): * eingestellt / justiert * * Behebungsmassnahme 2 (St\u00f6rungsursache): * ersetzt * * System BHM 3 (St\u00f6rungsursache): * v-Schwellen-Schaltung Notentriegelung * * Behebungsmassnahme 3 (St\u00f6rungsursache): * gepr\u00fcft gem. Checkliste * *"
#     },
#     "issue_128189630_log_8": {
#         "date_time": "21.04.2023 11:04:58",
#         "comment": "* Winkelgetriebeeinheit, Motorendanschlag und Umlenkrolle korrekt * positioniert, Schrauben und Spannscheiben ersetzt, mit korrektem * Drehmoment angezogen und markiert. * ZR Spannung eingestellt auf 43.3Hz, Frequenzdifferenz liegt bei 7Hz. und * ist I.O. * \u00dcbertotpunktlage mit Lampe und Spiegel kontrolliert, I.O. * Zeit f\u00fcr Wissensaustausch auch auf diese Meldung verbucht. *"
#     },
#     "issue_128189630_log_9": {
#         "date_time": "21.04.2023 14:49:59",
#         "comment": "* Bei Zugsausfahrt wurde festgestellt, dass die Gr\u00fcnschlaufe unterbrochen * ist und eine Fahrsperre vorliegt. * Diese T\u00fcr abgetrennt, Gr\u00fcnschlaufe nun I.O. * Im Gf Prim\u00e4rdrehfalle ausgemessen, diese hatte tw. einen Unterbruch. * Prim\u00e4rdrehfalle im Gf getauscht, mit Drehmoment festgezogen und * markiert. * Simulation durchgef\u00fchrt und \u00dcbertotpunktlage erneut kontrolliert, I.O."
#     },
#     "issue_128140205_log_1": {
#         "date_time": "21.06.2022 08:03:57",
#         "comment": "* System (St\u00f6rungsursache): * Einstiegssysteme --> Einstiegst\u00fcre --> T\u00fcrsteuerung & -bedienung * Zugebene --> ... * * Lokalisierung (St\u00f6rungsursache): * 2 * * Symptom (St\u00f6rungsbild): * pendelt * *"
#     },
#     "issue_128140205_log_2": {
#         "date_time": "21.06.2022 08:03:58",
#         "comment": "* T\u00fcre 02 Pendelte und liess sich nur noch mit T\u00fcrreset jeweils schliessen * -> Abgetrennt *"
#     },
#     "issue_128140205_log_3": {
#         "date_time": "01.07.2022 23:19:20",
#         "comment": "* T\u00fcre bleibt blockiert nach wenigen cm. Kommt sie \u00fcber den Punkt bleibt * sie ca 30cm vor Schliessung Blockiert. Gereinigt geschmiert *  ohne Erfolg. Untere Linearf\u00fchrung tauschen. Mat bestellt. *"
#     },
#     "issue_128140205_log_4": {
#         "date_time": "05.08.2022 13:56:26",
#         "comment": "* Diag: Anzugsmoment M6 Schraube Seite T\u00fcrblatt abgekl\u00e4rt. * Schraube soll nach 11618639 Seite 51 Allgemeine Anzugsmomente angezogen * werden (Schraubentyp konnte nicht abgekl\u00e4rt werden). * Erw.Mass: Linearf\u00fchrung unten ersetzen. *"
#     },
#     "issue_128140205_log_5": {
#         "date_time": "07.11.2022 21:06:56",
#         "comment": "* Erg\u00e4nzung aus Meldung 127555874: * Zahnriemenspannung der T\u00fcre ist zu gering muss eingestellt werden beim * Tausch der Linearf\u00fchrung *"
#     },
#     "issue_128140205_log_6": {
#         "date_time": "08.02.2023 14:04:17",
#         "comment": "* Ausfallart (St\u00f6rungsursache): * blockiert / verklemmt / schwerg\u00e4ngig * * System BHM 1 (St\u00f6rungsursache): * T\u00fcrsteuerung & -bedienung Zugebene * * Behebungsmassnahme 1 (St\u00f6rungsursache): * ersetzt * * System BHM 2 (St\u00f6rungsursache): * T\u00fcrsteuerung & -bedienung Zugebene * * Behebungsmassnahme 2 (St\u00f6rungsursache): * eingestellt / justiert * * System BHM 3 (St\u00f6rungsursache): * T\u00fcrsteuerung & -bedienung Zugebene * * Behebungsmassnahme 3 (St\u00f6rungsursache): * Test / Simulation durchgef\u00fchrt * *"
#     },
#     "issue_128140205_log_7": {
#         "date_time": "08.02.2023 14:04:17",
#         "comment": "* Untere Linearf\u00fchrung massiv verklemmt, diese getauscht, beide * Linearf\u00fchrungen richtig geschmiert und gereinigt. * Zahnriemenspannung war bei 34Hz. Diese eingestellt auf 44.2Hz. * IBS Protokoll nach AAZ 11618639 f\u00fcr Tausch Linearf\u00fchrungen durchgef\u00fchrt. * Dabei festgestellt, dass das X-Mass oben bei 73mm liegt, * die T\u00fcrblattparallelit\u00e4t beidseitig nicht stimmt und die Drehs\u00e4ulenh\u00f6he * zu klein ist (Ist 4mm, Soll 7-10mm) S\u00e4mtliche * Einstellungen auf Sollwert eingestellt, s\u00e4mtliche Schrauben und * Spannscheiben getauscht, mit Drehmoment angezogen und markiert. * \u00dcbertotpunktlage mit Lampe und Spiegel kontrolliert, diese ist I.O."
#     },
#     "issue_127402644_log_1": {
#         "date_time": "06.01.2023 09:26:15",
#         "comment": "* T\u00fcr muss ersetzt werden (MT5/3 Einstiegs Richtung LINKS) nach Absprache * mit PDT Thomas B\u00fchrer. Bitte neu planen. *"
#     },
#     "issue_127402644_log_2": {
#         "date_time": "06.01.2023 09:27:21",
#         "comment": "* Behebungsmassnahme 2 (St\u00f6rungsursache): * gepr\u00fcft gem. Checkliste * * System BHM 3 (St\u00f6rungsursache): * T\u00fcrblatt / T\u00fcrfl\u00fcgel komplett * *"
#     },
#     "issue_127402644_log_3": {
#         "date_time": "23.02.2023 15:35:22",
#         "comment": "* Betroffenes T\u00fcrblatt ist in der Reservierten Zone. Bitte bei Gelegenheit   tauschen *"
#     },
#     "issue_127402644_log_4": {
#         "date_time": "13.04.2023 07:54:17",
#         "comment": "* Status 19 gesetzt aufgrund Langl\u00e4ufer-Meldung (Bald 500 Tage offen) * Bitte T\u00fcrfl\u00fcgel ersetzen. *"
#     },
#     "issue_127402644_log_5": {
#         "date_time": "02.05.2023 16:01:30",
#         "comment": "* Mass: T\u00fcrfl\u00fcgel ersetzt und eingestellt. * Abdichtgummi oben musste gerichtet werden. * F\u00fchrungsschiene Fanghacken g\u00e4ngig gemacht. * IBS erfolgreich. T\u00fcre schl\u00e4gt leicht beim \u00f6ffnen, in Toleranz."
#     }
# }

# %%
#save df
df.to_csv("../data/interim/final_df2.csv", index=False)

# %%
# save json
json_file_path = '../data/interim/maintenance_logs.json'
with open(json_file_path, 'w',encoding='utf-8') as json_file:
    json.dump(log_dict, json_file, indent=4, ensure_ascii=False)

# %% [markdown]
# ### 3 - CREATE JSON FOR MENU

# %% [markdown]
# ####  3.1 - come dare priorità

# %%
# 3.1.1 - divido equamente i fault start date in 3 parti (si puo rivedere questo)
date_edges = [df["fault_start_date"].quantile(0.33), df["fault_start_date"].quantile(0.66)]
def assign_priority(date, edges):
    if date <= edges[0]:
        return 1
    elif date <= edges[1]:
        return 2
    else:
        return 3
# 3.1.2 - aggiungo la colonna 'priority'
df['priority'] = df['fault_start_date'].apply(assign_priority, edges=date_edges)

# %%
df.head(10)
# Out:
#   train_number                                 problem  log_number  \
# 0        015-5                Primärdrehfalle tauschen   131479425
# 1        001-5  -ET-Antriebsmotor 1 gestört-zeitwei...   131471966
# 2        047-8                -ET-Rechner 3 Stör.Aktiv   131461040
# 3        023-9           -ET-Rechner 2 schliesst nicht   131351602
# 4        113-8                     +ÜT moteur 5 bloqué   131332603
# 5        058-5                  ET 1 gestört-zeitweise   131304580
# 6        017-1                       -ET 1 n'ouvre pas   131280057
# 7        015-5                   -ET 2 schliesst nicht   131252085
# 8        048-6  -Schiebetritt Antrieb 2 fährt nicht...   131243142
# 9        030-4       -ET calculateur porte 4 déclenché   131198042
#
#                                      maintenance_log fault_start_date  \
# 0  [issue_131479425_log_1, issue_131479425_log_2,...       2024-09-18
# 1  [issue_131471966_log_1, issue_131471966_log_2,...       2024-09-17
# 2  [issue_131461040_log_1, issue_131461040_log_2,...       2024-09-14
# 3  [issue_131351602_log_1, issue_131351602_log_2,...       2024-08-18
# 4  [issue_131332603_log_1, issue_131332603_log_2,...       2024-08-14
# 5  [issue_131304580_log_1, issue_131304580_log_2,...       2024-08-08
# 6  [issue_131280057_log_1, issue_131280057_log_2,...       2024-08-01
# 7  [issue_131252085_log_1, issue_131252085_log_2,...       2024-07-25
# 8  [issue_131243142_log_1, issue_131243142_log_2,...       2024-07-23
# 9  [issue_131198042_log_1, issue_131198042_log_2,...       2024-07-11
#
#                               material_name  \
# 0    Drehfalle vollständig zu Einstiegstüre
# 1         Türsteuerung BODE 25-004-1019-301
# 2    Drehfalle vollständig zu Einstiegstüre
# 3                 Handschalter zu Türflügel
# 4  Türsteuerung MTS-L 1.14 zu Uebergangstür
# 5    Drehfalle vollständig zu Einstiegstüre
# 6         Türsteuerung BODE 25-004-1019-301
# 7    Drehfalle vollständig zu Einstiegstüre
# 8    Drehfalle vollständig zu Einstiegstüre
# 9         Türsteuerung BODE 25-004-1019-301
#
#                                    maintenance_steps  \
# 0          Sonstige → Test / Simulation durchgeführt
# 1                       HW/Elektr. & Mech. → ersetzt
# 2  HW/Elektr. & Mech. → ersetzt ; HW/Elektr. & Me...
# 3                       HW/Elektr. & Mech. → ersetzt
# 4                       HW/Elektr. & Mech. → ersetzt
# 5          Sonstige → Test / Simulation durchgeführt
# 6                       HW/Elektr. & Mech. → ersetzt
# 7  HW/Elektr. & Mech. → ersetzt ; Sonstige → gepr...
# 8  HW/Elektr. & Mech. → Messwert(e) ausgelesen / ...
# 9            Software → Update / Upgrade aufgespielt
#
#                                     cause_of_failure        BODE code door  \
# 0             Software & Firmware → übrige Störungen  25-341-0119-101    3
# 1  HW/Elektr. & Mech. - elektrisch → spricht nich...  25-004-1019-301    1
# 2  HW/Elektr. & Mech. - elektrisch → Fehler Daten...  25-341-0119-101    3
# 3  HW/Elektr. & Mech. - elektrisch → spricht unbe...  25-310-0566-202    2
# 4             Software & Firmware → übrige Störungen  25-004-1019-301    5
# 5            HW/Elektr. & Mech. - mechanisch → fehlt  25-341-0119-101    1
# 6  HW/Elektr. & Mech. - elektrisch → spricht nich...  25-004-1019-301    1
# 7  HW/Elektr. & Mech. - mechanisch → abgebrochen ...  25-341-0119-101    2
# 8  HW/Elektr. & Mech. - elektrisch → startet nich...  25-341-0119-101    2
# 9  HW/Elektr. & Mech. - elektrisch → startet nich...  25-004-1019-301    4
#
#    priority
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
# 5         3
# 6         3
# 7         3
# 8         3
# 9         3

# %% [markdown]
# #### 3.2 - crea JSON per il menu maintenance

# %%
# 3.2.1 - file json per il menu maintenance = priority, train number, door number, problem
mm_dict = {}
s = []
for i,row in df.iterrows():
    log = {
            'priority': row['priority'],
            'train_number': row['train_number'],
            'door_number': row['door'],
            'problem': row['problem']
        }
    s.append(log)
mm_dict['tasks'] = s
# save json
json_file_path = '../data/interim/maintenance_menu.json'
with open(json_file_path, 'w',encoding='utf-8') as json_file:
    json.dump(mm_dict, json_file, indent=4, ensure_ascii=False)

# %% [markdown]
# #### 3.3 - crea JSON per il menu steps

# %%
# 3.3.1 - file json per il menu steps = step number, step description, component code
steps = ['Close the door leaf.', 'On the inside of the left door leaf, remove 2 hexagonal socket screws from the cover of the door leaf distributor (SW 4).','Remove the cover of the distribution box.']
steps_BODE=['25-326-0300-201','25-714-6068-321','25-950-0002-309']
ms_dict = {}
s = []
for i,el in enumerate(steps):
    log = {
            'stepN': i,
            'step description': el,
            'component code': steps_BODE[i]
        }
    s.append(log)
ms_dict['name'] = '6.7.6_Türflügel_ausbauen'
ms_dict['steps'] = s
# save json
print(s)
json_file_path = '../data/interim/maintenance_steps_676.json'
with open(json_file_path, 'w') as json_file:
    json.dump(ms_dict, json_file, indent=4)
# Out:
# [{'stepN': 0, 'step description': 'Close the door leaf.', 'component code': '25-326-0300-201'}, {'stepN': 1, 'step description': 'On the inside of the left door leaf, remove 2 hexagonal socket screws from the cover of the door leaf distributor (SW 4).', 'component code': '25-714-6068-321'}, {'stepN': 2, 'step description': 'Remove the cover of the distribution box.', 'component code': '25-950-0002-309'}]

# %%
# FATTO
{
    'priority': '1-5',
    'train number': '2222',
    'door number': '3',
    'problem': '+ÜT moteur 5 bloqué'
}

# questo ce lo abbiamo gia no?
{
    'history': [
        {
            'date': '2021-01-01',
            'comment': 'Issue identified'
        },
        {
            'date': '2021-01-02',
            'comment': 'Issue fixed'
        }
    ],

    'how': 'avvia manuentizione'

}


{
    'step1': {'open the outer box', 'pezzo che si illumina', 'next button'},
    'step2': {'bla bla bla ', 'pezzo che si illumina', 'next button'},
    'step3': {'bla bla bla bla', 'pezzo che si illumina', 'next button'}
}

# After having concluded the maintenance, the user can close the issue and the issue will be removed from the list of issues
# Out:
# {'step1': {'next button', 'open the outer box', 'pezzo che si illumina'},
#  'step2': {'bla bla bla ', 'next button', 'pezzo che si illumina'},
#  'step3': {'bla bla bla bla', 'next button', 'pezzo che si illumina'}}
