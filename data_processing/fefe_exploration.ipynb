# %% [markdown]
# ## FEFE DATA EXLORATION

# %% [markdown]
# #### 1. FIX DATASET -> ASSOCIATE COMPONENTS WITH BODE CODE

# %%
# 1 - initial dataframe exploration from chris
import pandas as pd
datapath = "../data/raw/componentwise_dataset.xlsx"
df = pd.read_excel(datapath, sheet_name="Export")

cols_en = [
"Fault start date (MEL)",
"Short text (MEL)",
"Long text (MEL)",
"Message number (MEL)",
"Vehicle family (TPL)",
"Vehicle type (TPL)",
"Material (CO)",
"Material reference (MAT)",
"Material quantity ACTUAL",
"Material / unit of measure (CO)",
"WF screen symptom (MEL)",
"WF-cause-sys-1 (MEL) (H)",
"WF-cause-sys-2 (MEL) (H)",
"WF-Cause-Sys-3 (MEL) (H)",
"WF-Cause-Sys-4 (MEL) (H)",
"WF-Cause-Sys-5 (MEL) (H)",
"WF-cause-sys-6 (MEL) (H)",
"WF cause failure type (MEL)",
"WF-cause-fix.mass (1-3) (MEL)",
"Multiple unit / EW (TPL)",
"Functional location (TPL)",
"DIN code (H)",
"Design workstation (location) (MEL)"
]

cols_interst = [
"Fault start date (MEL)",
"Short text (MEL)",
"Long text (MEL)",
"Message number (MEL)",
"Material reference (MAT)",
"WF cause failure type (MEL)",
"WF-cause-fix.mass (1-3) (MEL)",
"Multiple unit / EW (TPL)",

]
df = df.loc[:1594]

df.columns = cols_en
df = df[cols_interst]

df.rename(columns={"Message number (MEL)" : "log_number",
                   "Multiple unit / EW (TPL)": "train_number",
                   "Fault start date (MEL)" : "fault_start_date",
                   "Short text (MEL)" : "problem",
                   "Long text (MEL)" : "maintenance_log",
                   "Material reference (MAT)": "material_description",
                   "WF cause failure type (MEL)": "cause_of_failure",
                   "WF-cause-fix.mass (1-3) (MEL)": "maintenance_steps",
                   "Material reference (MAT)": "material_name"}
                   , inplace=True)

df["fault_start_date"] = pd.to_datetime(df["fault_start_date"], format="%Y-%m-%d %H:%M:%S")
df["problem"] = df["problem"].astype(str)
df["maintenance_log"] = df["maintenance_log"].astype(str)
df["log_number"] = df["log_number"].astype(int)
df["train_number"] = df["train_number"].astype(str)
df["material_name"] = df["material_name"].astype(str)
df["maintenance_steps"] = df["maintenance_steps"].astype(str)
df["cause_of_failure"] = df["cause_of_failure"].astype(str)

# Ok it is always the same. Remove the prefix:
df["train_number"]= df["train_number"].str[10:]

# Reorder columns
df = df[["train_number", "problem", "log_number", "maintenance_log", "fault_start_date", 
         "material_name", "maintenance_steps", "cause_of_failure"]]

# %%
# 2 - associate components to bode code
components_bode_dict = {
    'SICHERHEITSGLAS': '25-351-0224-301',
    'ZAHNRIEMENRAD': '25-865-0011-301',
    'DREHFALLE': '25-341-0119-101',
    'WAHLSCHALTER': '25-714-0034-301',
    'TÜRSTEUERUNG': '25-004-1019-301',
    'ZAHNRIEMENRAD': '25-865-0011-301'
}

# keep only rows that have one of these components
def search_material_reference(row, search_dict):
    for key in search_dict.keys():
        if key.lower() in row['material_name'].lower():
            return True
    return False

filtered_df = df[df.apply(lambda row: search_material_reference(row, components_bode_dict), axis=1)]
filtered_df = filtered_df.drop_duplicates()

# add bode code
def add_bode_code(row, search_dict):
    for key, code in search_dict.items():
        if key.lower() in row['material_name'].lower() or row['maintenance_log'].lower():
            return code
    return None

filtered_df['BODE code'] = filtered_df.apply(lambda row: add_bode_code(row, components_bode_dict), axis=1)
print(filtered_df)
# Out:
#      train_number                                 problem  log_number  \
# 8           015-5                Primärdrehfalle tauschen   131479425
# 9           001-5  -ET-Antriebsmotor 1 gestört-zeitwei...   131471966
# 13          047-8                -ET-Rechner 3 Stör.Aktiv   131461040
# 15          043-7            -ÜT-Türrechner WE1 abgenutzt   131460609
# 50          113-8                     +ÜT moteur 5 bloqué   131332603
# ...           ...                                     ...         ...
# 1545        120-3           ET verrouillage 2 AAZ12578936   128404201
# 1546        120-3           ET verrouillage 3 AAZ12578936   128404202
# 1547        120-3           ET verrouillage 4 AAZ12578936   128404198
# 1557        024-7                  ET-Verriegelung 3 lose   128275990
# 1567        046-0     ET-v-Schwelle Notent 3 schwergängig   128189630
#
#                                         maintenance_log fault_start_date  \
# 8      * 18.09.2024 12:56:19 CET (U239359) * System ...       2024-09-18
# 9      * 17.09.2024 09:18:21 CET (U147283) Tel. +41 ...       2024-09-17
# 13     * 14.09.2024 06:23:11 CET (U224474) Tel. +41 ...       2024-09-14
# 15    * 13.09.2024 21:30:31 CET (U146319) Tel. +41 5...       2024-09-13
# 50     * 14.08.2024 22:07:53 CET (U210095) Tél. +41 ...       2024-08-14
# ...                                                 ...              ...
# 1545   * 26.08.2022 02:59:07 CET (U224840) Tel. +41 ...       2022-08-26
# 1546   * 26.08.2022 02:59:43 CET (U224840) Tel. +41 ...       2022-08-26
# 1547   * 26.08.2022 02:56:59 CET (U224840) Tel. +41 ...       2022-08-26
# 1557   * 26.07.2022 03:30:01 CET (U228671) Tel. +41 ...       2022-07-26
# 1567   * 04.07.2022 10:10:33 CET (U225459) Tel. +41 ...       2022-07-04
#
#                                  material_name  \
# 8       Drehfalle vollständig zu Einstiegstüre
# 9            Türsteuerung BODE 25-004-1019-301
# 13      Drehfalle vollständig zu Einstiegstüre
# 15    Türsteuerung MTS-L 1.14 zu Uebergangstür
# 50    Türsteuerung MTS-L 1.14 zu Uebergangstür
# ...                                        ...
# 1545    Drehfalle vollständig zu Einstiegstüre
# 1546    Drehfalle vollständig zu Einstiegstüre
# 1547    Drehfalle vollständig zu Einstiegstüre
# 1557    Drehfalle vollständig zu Einstiegstüre
# 1567    Drehfalle vollständig zu Einstiegstüre
#
#                                       maintenance_steps  \
# 8             Sonstige → Test / Simulation durchgeführt
# 9                          HW/Elektr. & Mech. → ersetzt
# 13    HW/Elektr. & Mech. → ersetzt ; HW/Elektr. & Me...
# 15    HW/Elektr. & Mech. → ersetzt ; Software → Upda...
# 50                         HW/Elektr. & Mech. → ersetzt
# ...                                                 ...
# 1545                 Sonstige → geprüft gem. Checkliste
# 1546                 Sonstige → geprüft gem. Checkliste
# 1547                 Sonstige → geprüft gem. Checkliste
# 1557                       HW/Elektr. & Mech. → ersetzt
# 1567  HW/Elektr. & Mech. → eingestellt / justiert ; ...
#
#                                        cause_of_failure        BODE code
# 8                Software & Firmware → übrige Störungen  25-351-0224-301
# 9     HW/Elektr. & Mech. - elektrisch → spricht nich...  25-351-0224-301
# 13    HW/Elektr. & Mech. - elektrisch → Fehler Daten...  25-351-0224-301
# 15               Software & Firmware → übrige Störungen  25-351-0224-301
# 50               Software & Firmware → übrige Störungen  25-351-0224-301
# ...                                                 ...              ...
# 1545  HW/Elektr. & Mech. - mechanisch → mechanische ...  25-351-0224-301
# 1546  HW/Elektr. & Mech. - mechanisch → mechanische ...  25-351-0224-301
# 1547  HW/Elektr. & Mech. - mechanisch → mechanische ...  25-351-0224-301
# 1557  HW/Elektr. & Mech. - mechanisch → lose / unzur...  25-351-0224-301
# 1567  HW/Elektr. & Mech. - mechanisch → blockiert / ...  25-351-0224-301
#
# [138 rows x 9 columns]

# %%
# 3 - save df
filtered_df.to_csv("../data/interim/final_df.csv", index=False)

# %% [markdown]
# #### 2. WORK ON MAINTENANCE LOG COLUMN

# %%
import pandas as pd
import json
import re

df = filtered_df
# extract log
def extract_logs(maintenance_log):
    log_pattern = r'(\d{2}\.\d{2}\.\d{4} \d{2}:\d{2}:\d{2}) CET.*Tel\. \+(\d+ \d{2} \d{3} \d{2} \d{2}).*\*\s*(.*)'
    matches = re.findall(log_pattern, maintenance_log)
    
    logs = []
    for match in matches:
        log = {
            "date_time": match[0],
            "telephone": match[1],
            "comment": match[2].strip(),
        }
        logs.append(log)
    
    return logs

log_dict = {}
for index, row in df.iterrows():
    logs = extract_logs(row['maintenance_log'])
    for i, log in enumerate(logs):
        key = f"issue_{int(row['log_number'])}_log_{i+1}"
        log_dict[key] = log

df['maintenance_log'] = df['log_number'].map(lambda log_number: [f"issue_{int(log_number)}_log_{i+1}" for i in range(len(extract_logs(df.loc[df['log_number'] == log_number, 'maintenance_log'].values[0])))])
print(df)

print(json.dumps(log_dict, indent=4))
# Out:
#      train_number                                 problem  log_number  \
# 8           015-5                Primärdrehfalle tauschen   131479425
# 9           001-5  -ET-Antriebsmotor 1 gestört-zeitwei...   131471966
# 13          047-8                -ET-Rechner 3 Stör.Aktiv   131461040
# 15          043-7            -ÜT-Türrechner WE1 abgenutzt   131460609
# 50          113-8                     +ÜT moteur 5 bloqué   131332603
# ...           ...                                     ...         ...
# 1545        120-3           ET verrouillage 2 AAZ12578936   128404201
# 1546        120-3           ET verrouillage 3 AAZ12578936   128404202
# 1547        120-3           ET verrouillage 4 AAZ12578936   128404198
# 1557        024-7                  ET-Verriegelung 3 lose   128275990
# 1567        046-0     ET-v-Schwelle Notent 3 schwergängig   128189630
#
#               maintenance_log fault_start_date  \
# 8     [issue_131479425_log_1]       2024-09-18
# 9     [issue_131471966_log_1]       2024-09-17
# 13    [issue_131461040_log_1]       2024-09-14
# 15    [issue_131460609_log_1]       2024-09-13
# 50    [issue_131332603_log_1]       2024-08-14
# ...                       ...              ...
# 1545  [issue_128404201_log_1]       2022-08-26
# 1546  [issue_128404202_log_1]       2022-08-26
# 1547  [issue_128404198_log_1]       2022-08-26
# 1557  [issue_128275990_log_1]       2022-07-26
# 1567  [issue_128189630_log_1]       2022-07-04
#
#                                  material_name  \
# 8       Drehfalle vollständig zu Einstiegstüre
# 9            Türsteuerung BODE 25-004-1019-301
# 13      Drehfalle vollständig zu Einstiegstüre
# 15    Türsteuerung MTS-L 1.14 zu Uebergangstür
# 50    Türsteuerung MTS-L 1.14 zu Uebergangstür
# ...                                        ...
# 1545    Drehfalle vollständig zu Einstiegstüre
# 1546    Drehfalle vollständig zu Einstiegstüre
# 1547    Drehfalle vollständig zu Einstiegstüre
# 1557    Drehfalle vollständig zu Einstiegstüre
# 1567    Drehfalle vollständig zu Einstiegstüre
#
#                                       maintenance_steps  \
# 8             Sonstige → Test / Simulation durchgeführt
# 9                          HW/Elektr. & Mech. → ersetzt
# 13    HW/Elektr. & Mech. → ersetzt ; HW/Elektr. & Me...
# 15    HW/Elektr. & Mech. → ersetzt ; Software → Upda...
# 50                         HW/Elektr. & Mech. → ersetzt
# ...                                                 ...
# 1545                 Sonstige → geprüft gem. Checkliste
# 1546                 Sonstige → geprüft gem. Checkliste
# 1547                 Sonstige → geprüft gem. Checkliste
# 1557                       HW/Elektr. & Mech. → ersetzt
# 1567  HW/Elektr. & Mech. → eingestellt / justiert ; ...
#
#                                        cause_of_failure        BODE code
# 8                Software & Firmware → übrige Störungen  25-351-0224-301
# 9     HW/Elektr. & Mech. - elektrisch → spricht nich...  25-351-0224-301
# 13    HW/Elektr. & Mech. - elektrisch → Fehler Daten...  25-351-0224-301
# 15               Software & Firmware → übrige Störungen  25-351-0224-301
# 50               Software & Firmware → übrige Störungen  25-351-0224-301
# ...                                                 ...              ...
# 1545  HW/Elektr. & Mech. - mechanisch → mechanische ...  25-351-0224-301
# 1546  HW/Elektr. & Mech. - mechanisch → mechanische ...  25-351-0224-301
# 1547  HW/Elektr. & Mech. - mechanisch → mechanische ...  25-351-0224-301
# 1557  HW/Elektr. & Mech. - mechanisch → lose / unzur...  25-351-0224-301
# 1567  HW/Elektr. & Mech. - mechanisch → blockiert / ...  25-351-0224-301
#
# [138 rows x 9 columns]
# {
#     "issue_131479425_log_1": {
#         "date_time": "18.09.2024 12:56:19",
#         "telephone": "41 79 587 67 55",
#         "comment": "Drehfalle ersetzt. IBS erfolgreich."
#     },
#     "issue_131471966_log_1": {
#         "date_time": "17.09.2024 09:18:21",
#         "telephone": "41 79 588 16 82",
#         "comment": ""
#     },
#     "issue_131461040_log_1": {
#         "date_time": "14.09.2024 06:23:11",
#         "telephone": "41 79 644 70 29",
#         "comment": "angeh\u00e4ngt"
#     },
#     "issue_131460609_log_1": {
#         "date_time": "13.09.2024 21:30:31",
#         "telephone": "41 79 644 70 29",
#         "comment": "mit anderer \u00dcT."
#     },
#     "issue_131332603_log_1": {
#         "date_time": "14.08.2024 22:07:53",
#         "telephone": "41 79 729 27 53",
#         "comment": "UHR GUILLAUME"
#     },
#     "issue_131280057_log_1": {
#         "date_time": "01.08.2024 07:39:06",
#         "telephone": "41 79 316 17 04",
#         "comment": ""
#     },
#     "issue_131252085_log_1": {
#         "date_time": "25.07.2024 08:46:52",
#         "telephone": "41 79 644 70 29",
#         "comment": "Prim\u00e4rdrehfalle getauscht und IBS nach Vorgabe durchgef\u00fchrt"
#     },
#     "issue_131243142_log_1": {
#         "date_time": "23.07.2024 06:08:19",
#         "telephone": "41 79 644 70 29",
#         "comment": "und Pr\u00fcfnummer Drehmomentschl\u00fcssel angeh\u00e4ngt"
#     },
#     "issue_131234440_log_1": {
#         "date_time": "20.07.2024 15:41:38",
#         "telephone": "41 79 246 10 51",
#         "comment": "Ini zum Abtrennen der T\u00fcr gerichtet und eingestellt."
#     },
#     "issue_131198042_log_1": {
#         "date_time": "11.07.2024 14:35:12",
#         "telephone": "41 79 729 27 53",
#         "comment": "UHR GUILLAUME"
#     },
#     "issue_131166571_log_1": {
#         "date_time": "03.07.2024 18:04:48",
#         "telephone": "41 79 644 70 29",
#         "comment": "T\u00fcr l\u00e4uft wieder einwandfrei und die \u00dcbertotpunktlage ist I.O."
#     },
#     "issue_131108393_log_1": {
#         "date_time": "19.06.2024 11:42:03",
#         "telephone": "41 79 729 27 53",
#         "comment": "UHR_LOPEZ_MOUGIN_ANDREETTI"
#     },
#     "issue_131032238_log_1": {
#         "date_time": "31.05.2024 19:22:11",
#         "telephone": "41 79 644 70 29",
#         "comment": "ebenfalls der Meldung angeh\u00e4ngt"
#     },
#     "issue_131026840_log_1": {
#         "date_time": "30.05.2024 13:27:30",
#         "telephone": "41 79 589 47 77",
#         "comment": "wir die Drehfalle Gewechselt alles I.O"
#     },
#     "issue_130980143_log_1": {
#         "date_time": "18.05.2024 16:30:26",
#         "telephone": "41 79 246 10 51",
#         "comment": "Meldung Schliessen."
#     },
#     "issue_130948419_log_1": {
#         "date_time": "10.05.2024 16:25:26",
#         "telephone": "41 79 401 07 99",
#         "comment": "UHR_LOPEZ"
#     },
#     "issue_130869119_log_1": {
#         "date_time": "20.04.2024 20:34:33",
#         "telephone": "41 51 282 63 70",
#         "comment": "Funktion i.O."
#     },
#     "issue_130845160_log_1": {
#         "date_time": "15.04.2024 15:07:36",
#         "telephone": "41 79 644 60 12",
#         "comment": "angeschlossen auf 17/16. Richtig angeschlossen und gepr\u00fcft. i.O"
#     },
#     "issue_130826836_log_1": {
#         "date_time": "10.04.2024 08:39:35",
#         "telephone": "41 79 587 67 55",
#         "comment": "Mass: Prim\u00e4rdrehfalle ersetzt. IBS erfolgreich."
#     },
#     "issue_130824060_log_1": {
#         "date_time": "09.04.2024 22:29:48",
#         "telephone": "41 79 644 70 29",
#         "comment": "Spannrolle mit 16,5Nm angezogen."
#     },
#     "issue_130822195_log_1": {
#         "date_time": "09.04.2024 11:36:24",
#         "telephone": "41 79 589 47 77",
#         "comment": ""
#     },
#     "issue_130714806_log_1": {
#         "date_time": "13.03.2024 11:40:17",
#         "telephone": "41 79 644 70 29",
#         "comment": "T\u00fcrrechner wird er\u00f6ffnet."
#     },
#     "issue_130694659_log_1": {
#         "date_time": "08.03.2024 17:48:56",
#         "telephone": "41 79 587 67 55",
#         "comment": "T\u00fcrsteuerung ersetzt. IBS erfolgreich."
#     },
#     "issue_130657025_log_1": {
#         "date_time": "28.02.2024 12:36:20",
#         "telephone": "41 79 644 70 29",
#         "comment": "angeh\u00e4ngt."
#     },
#     "issue_130656492_log_1": {
#         "date_time": "28.02.2024 10:33:20",
#         "telephone": "41 79 644 70 29",
#         "comment": "Drehfalle getauscht und IBS nach Vorgabe durchgef\u00fchrt."
#     },
#     "issue_130515558_log_1": {
#         "date_time": "25.01.2024 14:19:54",
#         "telephone": "41 79 398 92 02",
#         "comment": "Die schwarzen Winkelgetriebe sind freigegeben."
#     },
#     "issue_130428173_log_1": {
#         "date_time": "03.01.2024 14:22:56",
#         "telephone": "41 79 894 26 94",
#         "comment": "Wurde durch MR371 erledigt."
#     },
#     "issue_130345569_log_1": {
#         "date_time": "12.12.2023 12:09:26",
#         "telephone": "41 79 729 27 53",
#         "comment": "Rempli protocoll e.o."
#     },
#     "issue_130326719_log_1": {
#         "date_time": "07.12.2023 11:30:56",
#         "telephone": "41 79 685 79 40",
#         "comment": "Prim\u00e4rdrehfalle ersetzt und IBS durchgef\u00fchrt."
#     },
#     "issue_130296253_log_1": {
#         "date_time": "30.11.2023 17:04:26",
#         "telephone": "41 79 246 10 51",
#         "comment": ""
#     },
#     "issue_130130787_log_1": {
#         "date_time": "21.10.2023 12:10:53",
#         "telephone": "41 79 246 10 51",
#         "comment": "T\u00fcr funktioniert"
#     },
#     "issue_130118691_log_1": {
#         "date_time": "18.10.2023 11:54:05",
#         "telephone": "41 79 725 51 42",
#         "comment": "T\u00fcre l\u00e4sst sich wieder bewegen io"
#     },
#     "issue_130074431_log_1": {
#         "date_time": "08.10.2023 16:27:45",
#         "telephone": "41 79 644 70 29",
#         "comment": "wieder einwandfrei."
#     },
#     "issue_130035549_log_1": {
#         "date_time": "28.09.2023 15:28:55",
#         "telephone": "41 79 129 68 55",
#         "comment": "durchgef\u00fchrt -> T\u00fcre in Betrieb, i.O"
#     },
#     "issue_130015217_log_1": {
#         "date_time": "23.09.2023 17:57:22",
#         "telephone": "41 79 725 51 42",
#         "comment": "Scheibe ersetzt io"
#     },
#     "issue_129898236_log_1": {
#         "date_time": "27.08.2023 16:51:33",
#         "telephone": "41 79 644 70 29",
#         "comment": "T\u00fcr schliesst nun wieder einwandfrei."
#     },
#     "issue_129742493_log_1": {
#         "date_time": "18.07.2023 16:31:02",
#         "telephone": "41 79 587 67 55",
#         "comment": "Funktionskontrolle i.O.."
#     },
#     "issue_129716448_log_1": {
#         "date_time": "13.07.2023 14:31:02",
#         "telephone": "41 79 928 24 75",
#         "comment": "R\u00fcckmeldung an D\u00fcrre Marius Werk Olten wenn Fehler gefunden worden ist."
#     },
#     "issue_129522739_log_1": {
#         "date_time": "02.06.2023 10:51:13",
#         "telephone": "41 51 220 60 40",
#         "comment": ""
#     },
#     "issue_129459697_log_1": {
#         "date_time": "17.05.2023 16:46:13",
#         "telephone": "41 79 725 51 42",
#         "comment": "T\u00fcre l\u00e4uft wieder einwandfrei io"
#     },
#     "issue_129453664_log_1": {
#         "date_time": "16.05.2023 15:52:50",
#         "telephone": "41 79 644 60 12",
#         "comment": "angeh\u00e4ngt."
#     },
#     "issue_129421279_log_1": {
#         "date_time": "09.05.2023 01:13:44",
#         "telephone": "41 79 587 67 55",
#         "comment": "IBS durchgef\u00fchrt und alles zusammengebaut."
#     },
#     "issue_129313895_log_1": {
#         "date_time": "11.04.2023 15:33:04",
#         "telephone": "41 79 129 66 47",
#         "comment": "Meldung wird geschlossen wegen Doppelmeldung (Mnr. 129314024)"
#     },
#     "issue_129221574_log_1": {
#         "date_time": "18.03.2023 18:37:36",
#         "telephone": "41 79 729 27 53",
#         "comment": "K1-K9 konnte von Bode eingestellt werden T\u00fcre wieder i.o"
#     },
#     "issue_129189310_log_1": {
#         "date_time": "10.03.2023 07:14:03",
#         "telephone": "41 79 644 60 12",
#         "comment": "IOW K\u00dcM: Relais K2 defekt. ET Rechner agw und neu geladen. wieder i.o."
#     },
#     "issue_129171706_log_1": {
#         "date_time": "06.03.2023 14:58:13",
#         "telephone": "41 79 639 26 89",
#         "comment": "Prim\u00e4rdrehfalle ersetzt, i.o."
#     },
#     "issue_129171707_log_1": {
#         "date_time": "06.03.2023 14:58:48",
#         "telephone": "41 79 639 26 89",
#         "comment": "Prim\u00e4rdrehfalle ersetzt, i.o."
#     },
#     "issue_129163856_log_1": {
#         "date_time": "03.03.2023 23:29:26",
#         "telephone": "41 79 246 10 51",
#         "comment": "T\u00fcrrechner getauscht und SW geladen. Getestet, i.O."
#     },
#     "issue_129120091_log_1": {
#         "date_time": "21.02.2023 15:26:04",
#         "telephone": "41 79 639 26 89",
#         "comment": "ersetzt i.o."
#     },
#     "issue_129120093_log_1": {
#         "date_time": "21.02.2023 15:27:19",
#         "telephone": "41 79 639 26 89",
#         "comment": "ersetzt i.o."
#     },
#     "issue_129114969_log_1": {
#         "date_time": "20.02.2023 15:37:46",
#         "telephone": "41 79 587 67 55",
#         "comment": ""
#     },
#     "issue_129105941_log_1": {
#         "date_time": "17.02.2023 15:39:09",
#         "telephone": "41 79 591 51 86",
#         "comment": "mehr getauscht werden."
#     },
#     "issue_129105933_log_1": {
#         "date_time": "17.02.2023 15:36:14",
#         "telephone": "41 79 591 51 86",
#         "comment": "mehr getauscht werden."
#     },
#     "issue_129105942_log_1": {
#         "date_time": "17.02.2023 15:39:40",
#         "telephone": "41 79 591 51 86",
#         "comment": "mehr getauscht werden."
#     },
#     "issue_129105943_log_1": {
#         "date_time": "17.02.2023 15:40:13",
#         "telephone": "41 79 591 51 86",
#         "comment": "mehr getauscht werden."
#     },
#     "issue_129105946_log_1": {
#         "date_time": "17.02.2023 15:41:46",
#         "telephone": "41 79 591 51 86",
#         "comment": "mehr getauscht werden."
#     },
#     "issue_129105928_log_1": {
#         "date_time": "17.02.2023 15:37:25",
#         "telephone": "41 79 639 26 89",
#         "comment": "Prim. Drehfalle ersetzt, i.o."
#     },
#     "issue_129102365_log_1": {
#         "date_time": "16.02.2023 15:48:38",
#         "telephone": "41 79 591 51 86",
#         "comment": "mehr getauscht werden."
#     },
#     "issue_129102366_log_1": {
#         "date_time": "16.02.2023 15:49:55",
#         "telephone": "41 79 591 51 86",
#         "comment": "mehr getauscht werden."
#     },
#     "issue_129102367_log_1": {
#         "date_time": "16.02.2023 15:50:43",
#         "telephone": "41 79 591 51 86",
#         "comment": "mehr getauscht werden."
#     },
#     "issue_129102370_log_1": {
#         "date_time": "16.02.2023 15:52:31",
#         "telephone": "41 79 591 51 86",
#         "comment": "mehr getauscht werden."
#     },
#     "issue_129102374_log_1": {
#         "date_time": "16.02.2023 15:54:11",
#         "telephone": "41 79 591 51 86",
#         "comment": "mehr getauscht werden."
#     },
#     "issue_129102375_log_1": {
#         "date_time": "16.02.2023 15:55:30",
#         "telephone": "41 79 639 26 89",
#         "comment": "Prim\u00e4rdrehfalle ersetzt i.o."
#     },
#     "issue_129102376_log_1": {
#         "date_time": "16.02.2023 15:56:23",
#         "telephone": "41 79 587 67 55",
#         "comment": "Mass: Festgezogen, markiert."
#     },
#     "issue_129102377_log_1": {
#         "date_time": "16.02.2023 15:57:46",
#         "telephone": "41 79 587 67 55",
#         "comment": "Mass: Festgezogen, markiert."
#     },
#     "issue_129098553_log_1": {
#         "date_time": "15.02.2023 17:52:14",
#         "telephone": "41 79 639 26 89",
#         "comment": "UHR GUILLAUME LOPEZ"
#     },
#     "issue_129098684_log_1": {
#         "date_time": "15.02.2023 17:53:02",
#         "telephone": "41 79 639 26 89",
#         "comment": "UHR GUILLAUME LOPEZ"
#     },
#     "issue_129067658_log_1": {
#         "date_time": "08.02.2023 09:35:34",
#         "telephone": "41 79 725 51 42",
#         "comment": "T\u00fcre 4 ist mit Spannset gesichert vorgefunden und korrekt bezetelt."
#     },
#     "issue_129062211_log_1": {
#         "date_time": "07.02.2023 12:53:31",
#         "telephone": "41 79 639 26 89",
#         "comment": "Prim\u00e4rdrehfalle wurde durch Bode ersetzt, i.o."
#     },
#     "issue_129056934_log_1": {
#         "date_time": "06.02.2023 12:54:13",
#         "telephone": "41 79 644 70 29",
#         "comment": "\u00dcbertotpunktlage mit Lampe und Spiegel kontrolliert, I.O."
#     },
#     "issue_129056933_log_1": {
#         "date_time": "06.02.2023 12:53:38",
#         "telephone": "41 79 644 70 29",
#         "comment": "\u00dcbertotpunktlage mit Lampe und Spiegel kontrolliert, I.O."
#     },
#     "issue_129042743_log_1": {
#         "date_time": "02.02.2023 09:33:58",
#         "telephone": "41 79 729 27 53",
#         "comment": ""
#     },
#     "issue_129042740_log_1": {
#         "date_time": "02.02.2023 09:32:45",
#         "telephone": "41 79 729 27 53",
#         "comment": ""
#     },
#     "issue_129011557_log_1": {
#         "date_time": "25.01.2023 15:41:28",
#         "telephone": "41 79 129 66 47",
#         "comment": "Beim pr\u00fcfprotokoll festgestellt das parallelma\u00df nicht In Ordnung ,"
#     },
#     "issue_128998835_log_1": {
#         "date_time": "23.01.2023 07:48:19",
#         "telephone": "41 79 639 26 89",
#         "comment": "ausgerissen. Umlenkrolle komplett ersetzt. i.o."
#     },
#     "issue_128990651_log_1": {
#         "date_time": "20.01.2023 14:42:08",
#         "telephone": "41 79 398 92 02",
#         "comment": "Weiterhin Alarmierung auf DDS 2009,7009 gesetzt. Meldung geschlossen."
#     },
#     "issue_128957759_log_1": {
#         "date_time": "12.01.2023 11:03:47",
#         "telephone": "41 79 639 26 89",
#         "comment": "Motorendanschlag ersetzt, i.o."
#     },
#     "issue_128911936_log_1": {
#         "date_time": "01.01.2023 03:41:08",
#         "telephone": "41 79 587 67 55",
#         "comment": "SW geladen. Funktion kontrolliert."
#     },
#     "issue_128881284_log_1": {
#         "date_time": "23.12.2022 07:42:21",
#         "telephone": "41 79 129 68 55",
#         "comment": "==>> gepr\u00fcft alles i.O"
#     },
#     "issue_128835897_log_1": {
#         "date_time": "12.12.2022 12:52:48",
#         "telephone": "41 79 644 70 29",
#         "comment": "Instruktion Nikos Schliesskraftmessger\u00e4t."
#     },
#     "issue_128771556_log_1": {
#         "date_time": "25.11.2022 16:00:45",
#         "telephone": "41 79 398 92 02",
#         "comment": ""
#     },
#     "issue_128768084_log_1": {
#         "date_time": "24.11.2022 15:37:46",
#         "telephone": "41 79 729 27 53",
#         "comment": "UHR"
#     },
#     "issue_128768091_log_1": {
#         "date_time": "24.11.2022 15:42:53",
#         "telephone": "41 79 729 27 53",
#         "comment": "UHR"
#     },
#     "issue_128768068_log_1": {
#         "date_time": "24.11.2022 15:42:19",
#         "telephone": "41 79 729 27 53",
#         "comment": "UHR"
#     },
#     "issue_128752218_log_1": {
#         "date_time": "21.11.2022 14:54:17",
#         "telephone": "41 79 729 27 53",
#         "comment": "UHR"
#     },
#     "issue_128752216_log_1": {
#         "date_time": "21.11.2022 14:53:21",
#         "telephone": "41 79 729 27 53",
#         "comment": ""
#     },
#     "issue_128729047_log_1": {
#         "date_time": "15.11.2022 09:46:52",
#         "telephone": "41 79 639 26 89",
#         "comment": ""
#     },
#     "issue_128729053_log_1": {
#         "date_time": "15.11.2022 09:51:44",
#         "telephone": "41 79 639 26 89",
#         "comment": "UHR"
#     },
#     "issue_128729095_log_1": {
#         "date_time": "15.11.2022 09:58:35",
#         "telephone": "41 79 639 26 89",
#         "comment": ""
#     },
#     "issue_128729596_log_1": {
#         "date_time": "15.11.2022 12:23:23",
#         "telephone": "41 79 639 26 89",
#         "comment": "UHR"
#     },
#     "issue_128729091_log_1": {
#         "date_time": "15.11.2022 09:54:24",
#         "telephone": "41 79 639 26 89",
#         "comment": ""
#     },
#     "issue_128729097_log_1": {
#         "date_time": "15.11.2022 09:59:46",
#         "telephone": "41 79 639 26 89",
#         "comment": ""
#     },
#     "issue_128716097_log_1": {
#         "date_time": "11.11.2022 15:38:37",
#         "telephone": "41 79 591 51 86",
#         "comment": "Durch den Nachweis CAA 12591260 wurde die tempor\u00e4re Neupositionierung   des Anschlag gem\u00e4ss Sonderfreigabe AAZ 12578936 in eine korrekte   Abhilfemassnahme \u00fcberf\u00fchrt. Die Meldung wird geschlossen"
#     },
#     "issue_128404190_log_1": {
#         "date_time": "26.08.2022 02:48:07",
#         "telephone": "41 79 729 27 53",
#         "comment": "une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404195_log_1": {
#         "date_time": "26.08.2022 02:52:52",
#         "telephone": "41 79 725 51 42",
#         "comment": "une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404191_log_1": {
#         "date_time": "26.08.2022 02:48:57",
#         "telephone": "41 79 725 51 42",
#         "comment": "une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404197_log_1": {
#         "date_time": "26.08.2022 02:55:55",
#         "telephone": "41 79 725 51 42",
#         "comment": "une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404194_log_1": {
#         "date_time": "26.08.2022 02:51:45",
#         "telephone": "41 79 725 51 42",
#         "comment": ""
#     },
#     "issue_128404204_log_1": {
#         "date_time": "26.08.2022 03:00:29",
#         "telephone": "41 79 725 51 42",
#         "comment": "une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404193_log_1": {
#         "date_time": "26.08.2022 02:50:34",
#         "telephone": "41 79 725 51 42",
#         "comment": "une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404200_log_1": {
#         "date_time": "26.08.2022 02:58:25",
#         "telephone": "41 79 725 51 42",
#         "comment": "une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404196_log_1": {
#         "date_time": "26.08.2022 02:53:41",
#         "telephone": "41 79 725 51 42",
#         "comment": "une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404201_log_1": {
#         "date_time": "26.08.2022 02:59:07",
#         "telephone": "41 79 725 51 42",
#         "comment": "une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404202_log_1": {
#         "date_time": "26.08.2022 02:59:43",
#         "telephone": "41 79 725 51 42",
#         "comment": "une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128404198_log_1": {
#         "date_time": "26.08.2022 02:56:59",
#         "telephone": "41 79 725 51 42",
#         "comment": "une mesure corrective correcte. La notification est close\"."
#     },
#     "issue_128275990_log_1": {
#         "date_time": "26.07.2022 03:30:01",
#         "telephone": "41 79 587 67 55",
#         "comment": ""
#     },
#     "issue_128189630_log_1": {
#         "date_time": "04.07.2022 10:10:33",
#         "telephone": "41 79 644 70 29",
#         "comment": "Simulation durchgef\u00fchrt und \u00dcbertotpunktlage erneut kontrolliert, I.O."
#     }
# }

# %%
#save df
df.to_csv("../data/interim/final_df2.csv", index=False)

# %%
# save json
json_file_path = '../data/interim/maintenance_logs.json'
with open(json_file_path, 'w') as json_file:
    json.dump(log_dict, json_file, indent=4)
